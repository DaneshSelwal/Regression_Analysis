# %% [markdown]
# # **Start**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ["PIP_CONSTRAINT"] = "/tmp/numpy_constraint.txt"
# !echo "numpy==1.26.4" > /tmp/numpy_constraint.txt

# !pip uninstall -y torch torchaudio torchvision \
    torchao torchcodec torchdata torchtune torchsummary -q 2>/dev/null

# !pip uninstall -y tensorflow tensorflow-text tensorflow-hub tf-keras \
    tensorflow_decision_forests tensorflow-probability \
    tensorflow-Datasets tensorflow-metadata -q 2>/dev/null

# !pip uninstall -y numpy scikit-learn shap xgboost lightgbm dask \
    seaborn plotly openpyxl Cython catboost interpret lime -q 2>/dev/null

# !pip install numpy==1.26.4 -q
# !pip install scikit-learn==1.6.1 -q
# !pip install torch==2.9.0 -q

# !pip install lightgbm==4.6.0 -q
# !pip install xgboost==3.1.2 -q
# !pip install catboost==1.2.8 -q
# !pip install gpboost==1.6.1 -q
# !pip install ngboost==0.5.8 -q
# !pip install pgbm==2.2.0 -q
# !pip install pytorch-tabnet2==4.5.3 -q

# !pip install bayesian-optimization==3.2.0 -q
# !pip install optuna==4.6.0 -q
# !pip install optunahub==0.4.0 -q
# !pip install cmaes==0.12.0 -q

# !pip install shap==0.44.0 -q
# !pip install lime==0.2.0.1 -q
# !pip install interpret==0.7.4 -q

# !pip install mapie==0.6.0 -q
# !pip install puncc==0.8.0 -q
# !pip install skorch==1.3.1 -q
# !pip install properscoring==0.1 -q

# !pip install dask[dataframe]==2025.12.0 -q
# !pip install cython==3.0.12 -q
# !pip install seaborn==0.13.2 -q
# !pip install plotly==5.24.1 -q
# !pip install kaleido==1.2.0 -q
# !pip install openpyxl==3.1.5 -q
# !pip install XlsxWriter==3.2.9 -q
# !pip install cp==2020.12.3 -q

# !pip install numpy==1.26.4 --force-reinstall --no-deps -q

os._exit(0)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 94.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# umap-learn 0.5.12 requires scikit-learn>=1.6, which is not installed.
# splot 1.1.7 requires seaborn>=0.11.0, which is not installed.
# pynndescent 0.6.0 requires scikit-learn>=0.18, which is not installed.
# libpysal 4.14.1 requires scikit-learn>=1.4.0, which is not installed.
# sklearn-pandas 2.2.0 requires scikit-learn>=0.23.0, which is not installed.
# pysal 25.7 requires scikit-learn>=1.1, which is not installed.
# cufflinks 0.17.3 requires plotly>=4.1.1, which is not installed.
# peft 0.19.1 requires torch>=1.13.0, which is not installed.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, which is not installed.
# segregation 2.5.4 requires scikit-learn>=0.21.3, which is not installed.
# segregation 2.5.4 requires seaborn, which is not installed.
# ydf-tf 2.20.0 requires tensorflow==2.20.0, which is not installed.
# spopt 0.7.0 requires scikit-learn>=1.4.0, which is not installed.
# hdbscan 0.8.42 requires scikit-learn>=1.6, which is not installed.
# accelerate 1.13.0 requires torch>=2.0.0, which is not installed.
# mapclassify 2.10.0 requires scikit-learn>=1.4, which is not installed.
# librosa 0.11.0 requires scikit-learn>=1.1.0, which is not installed.
# fastai 2.8.7 requires scikit-learn, which is not installed.
# fastai 2.8.7 requires torch<3,>=1.10, which is not installed.
# fastai 2.8.7 requires torchvision>=0.11, which is not installed.
# keras-hub 0.26.0 requires tensorflow-text; platform_system != "Windows", which is not installed.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# dopamine-rl 4.1.2 requires tensorflow-probability>=0.13.0, which is not installed.
# dopamine-rl 4.1.2 requires tf-keras>=2.18.0, which is not installed.
# tsfresh 0.21.1 requires scikit-learn>=0.22.0, which is not installed.
# missingno 0.5.2 requires seaborn, which is not installed.
# imbalanced-learn 0.14.1 requires scikit-learn<2,>=1.4.2, which is not installed.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, which is not installed.
# sentence-transformers 5.4.1 requires scikit-learn>=0.22.0, which is not installed.
# sentence-transformers 5.4.1 requires torch>=1.11.0, which is not installed.
# geemap 0.37.2 requires plotly, which is not installed.
# esda 2.9.0 requires scikit-learn>=1.4, which is not installed.
# spreg 1.9.0 requires scikit-learn>=0.22, which is not installed.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 50.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# segregation 2.5.4 requires seaborn, which is not installed.
# fastai 2.8.7 requires torch<3,>=1.10, which is not installed.
# fastai 2.8.7 requires torchvision>=0.11, which is not installed.
# sentence-transformers 5.4.1 requires torch>=1.11.0, which is not installed.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 46.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 52.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 52.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 7.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.8.7 requires torchvision>=0.11, which is not installed.
# timm 1.0.26 requires torchvision, which is not installed.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 37.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 121.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 37.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.1/409.1 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 12.2 MB/s eta 0:00:00
#   Building wheel for autograd-gamma (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 19.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 16.4 MB/s eta 0:00:00
#   Building wheel for pgbm (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.9/70.9 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.7/449.7 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 41.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for shap (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.0/244.0 kB 18.6 MB/s eta 0:00:00
#   Building wheel for lime (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 39.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 32.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 55.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 73.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 54.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.9/778.9 kB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 64.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.8/269.8 kB 16.7 MB/s eta 0:00:00
#   Building wheel for dash-cytoscape (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.5/268.5 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 34.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 41.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for cp (setup.py) ... done

# %% [markdown]
# # **Imports**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ngboost
import gpboost
from scipy.stats import randint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from gpboost import GPBoostRegressor
from ngboost import NGBRegressor
import optuna
import optunahub
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from interpret import show
from interpret.blackbox import LimeTabular, ShapKernel
from optuna.samplers import RandomSampler
import random
import time
from ngboost.distns import Normal
from ngboost.scores import LogScore
from scipy.stats import norm
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from interpret.glassbox import ExplainableBoostingRegressor
from interpret import show
import plotly.express as px
from io import BytesIO
from openpyxl import Workbook, load_workbook
import os
from openpyxl.drawing.image import Image as openpyxlImage
import warnings
import xlsxwriter
from openpyxl.drawing.image import Image
from pgbm.sklearn import HistGradientBoostingRegressor
import torch
from pgbm.torch import PGBM
import plotly.graph_objects as go
warnings.filterwarnings('ignore')
import pickle
import json
from pytorch_tabnet import TabNetRegressor

# %%
# Go to find & replace button and replace (water_quality_wqi_uncertainty_analysis) with your folder name. Rename your train and test Dataset as train.csv and test.csv.
# Modify the names of the feature in the below cell.
# Replace (WQI) with actual data label name.

# %%
feature_names = ['R1', 'R2', 'R3', 'R4', 'R5', 'R6', 'R7', 'R8', 'R9', 'R10', 'R11', 'R12', 'R13', 'R14', 'R15', 'R16', 'R17', 'R18', 'R19', 'R20', 'R21', 'R22', 'R23', 'R24', 'R25', 'R26', 'R27', 'R28', 'R29', 'R30', 'R31', 'R32', 'R33', 'R34', 'R35', 'R36', 'R37', 'R38', 'R39', 'R40', 'R41', 'R42', 'R43', 'R44', 'R45', 'R46', 'R47', 'R48', 'R49', 'R50', 'R51', 'R52', 'R53', 'R54', 'R55', 'R56', 'R57', 'R58', 'R59', 'R60', 'R61', 'R62', 'R63', 'R64', 'R65', 'R66', 'R67', 'R68', 'R69', 'R70', 'R71', 'R72', 'R73', 'R74', 'R75', 'R76', 'R77', 'R78', 'R79', 'R80', 'R81', 'R82', 'R83', 'R84', 'R85', 'R86', 'R87', 'R88', 'R89', 'R90', 'R91', 'R92', 'R93', 'R94', 'R95', 'R96', 'R97', 'R98', 'R99', 'R100', 'R101', 'R102', 'R103', 'R104', 'R105', 'R106', 'R107', 'R108', 'R109', 'R110', 'R111', 'R112', 'R113', 'R114', 'R115', 'R116', 'R117', 'R118', 'R119', 'R120', 'R121', 'R122', 'R123', 'R124', 'R125', 'R126', 'R127', 'R128', 'R129', 'R130', 'R131', 'R132', 'R133', 'R134', 'R135', 'R136', 'R137', 'R138', 'R139', 'R140', 'R141', 'R142', 'R143', 'R144', 'R145', 'R146', 'R147', 'R148', 'R149', 'R150', 'R151']

# %%
train_data_path = "./drive/MyDrive/water_quality_wqi_uncertainty_analysis/data/train.csv"
test_data_path = "./drive/MyDrive/water_quality_wqi_uncertainty_analysis/data/test.csv"
train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)
print("Training data loaded successfully.")
print("Test data loaded successfully.")
# Out:
# Training data loaded successfully.
# Test data loaded successfully.

# %%
print("\nShape of training data:", train_data.shape)
print("First 5 rows of training data:\n", train_data.head(5))
print("\nShape of test data:", test_data.shape)
print("First 5 rows of test data:\n", test_data.head(5))
# Out:
# Shape of training data: (190, 152)
# First 5 rows of training data:
#         R1      R2      R3      R4      R5      R6      R7      R8      R9  \
# 0  3.5960  3.6080  3.0100  3.6130  3.3760  2.2780  1.3410  3.4570  3.3540
# 1  2.9540  3.0470  3.1160  4.2640  4.4090  3.4810  2.3760  3.4030  3.4320
# 2  2.4870  2.9430  2.5290  3.7280  2.9870  1.8890  1.9960  2.1020  1.6180
# 3  1.3640  1.4186  1.3789  1.4776  1.5063  1.4047  1.2648  1.5166  1.5443
# 4  1.3074  1.3820  1.3476  1.3986  1.3403  1.3004  1.3719  1.3984  1.3865
#
#       R10  ...    R143    R144    R145    R146    R147   R148    R149    R150  \
# 0  1.9900  ...  2.7930  1.9660  2.3070  1.5280  1.9380  3.371  2.2060  1.5220
# 1  2.6350  ...  3.0260  2.3530  2.0400  1.7400  2.6250  4.026  2.9010  1.7450
# 2  1.2720  ...  1.2760  1.5990  1.8610  1.0290  1.8690  3.905  2.3200  1.3310
# 3  1.3834  ...  1.2223  1.0919  1.0995  1.0856  1.1728  1.315  1.2341  1.0753
# 4  1.3964  ...  1.1691  1.0689  1.1230  1.1384  1.1810  1.235  1.1589  1.1013
#
#      R151  WQI
# 0  1.7780  333
# 1  1.8710  222
# 2  1.2180  212
# 3  0.9929  116
# 4  1.0892  111
#
#   -2.42261838e-01 -4.38539039e-01  6.97179187e-02 -2.61918690e-01
#   -1.00629373e+00 -1.20948342e+00 -5.69952544e-01 -6.81318863e-01
#   -1.05135392e+00 -9.17627657e-01 -1.56702942e+00 -1.45737166e+00
#   -5.37063116e-01 -5.13840997e-01 -8.24549425e-01 -8.59230767e-01
#   -5.05386348e-01 -8.04662174e-01 -9.97401648e-01 -7.81664758e-01
#   -3.13666700e-01 -5.80223396e-01 -4.30185817e-01  1.09917264e-01
#   -5.00027960e-01 -8.94606238e-01 -7.79152416e-01 -6.40829553e-01
#   -1.26929466e+00 -1.48599708e+00 -1.01823513e+00 -6.97472529e-01
#   -6.55763689e-01 -8.40583611e-01 -1.04437714e+00 -9.29187637e-01
#   -8.46905331e-01 -1.04592270e+00 -1.59149083e+00 -1.49515363e+00
#   -1.04540431e+00 -7.01172725e-01 -6.59050982e-01 -5.16317785e-01
#   -5.83049433e-01 -1.01207570e+00 -9.93874355e-01 -9.83537348e-01
#   -9.50177764e-01 -7.53505381e-01 -6.85568795e-01 -6.03045991e-01
#   -4.04272414e-01 -3.63160453e-01 -4.46856467e-01 -6.98607028e-01
#   -1.09395583e+00 -9.67994562e-01 -6.28412852e-01 -3.32431339e-01
#   -4.10979349e-01 -5.40805904e-01 -5.79540664e-01 -5.04743920e-01
#   -7.00121417e-01 -5.34311672e-01 -3.81162536e-01 -1.15678397e+00
#   -1.19197298e+00 -8.82239880e-01 -6.69349623e-01 -3.04809858e-01
#   -1.11312749e+00 -1.69709766e+00 -4.95045563e-01 -7.12527408e-01
#   -1.38572549e+00 -1.06895771e+00 -1.53308202e+00 -8.73020289e-01
#   -8.52478054e-01 -1.60261085e+00 -8.36230728e-01 -3.47691934e-01
#   -4.39048629e-01 -6.21093673e-01 -4.55704793e-01 -6.24058928e-01
#   -1.33811014e+00 -1.01745165e+00 -3.83831978e-01 -3.59281584e-01
#   -1.03304982e+00 -8.70828456e-01 -5.64603026e-01 -5.59323372e-01
#   -9.50369133e-01 -6.35271509e-01 -1.36860048e-01]]

# %% [markdown]
# # **Functions**

# %%
import os

def _ensure_parent_dir(path):
    parent = os.path.dirname(path)
    if parent:
        os.makedirs(parent, exist_ok=True)
    return path

import os
def plot_best_scores(best_scores_ran, excel_file_path):
    # Extract the best pruner for each model based on RMSE and correlation coefficient
    best_rmse_scores = {}
    best_corr_coef_scores = {}

    for (model_name, pruner_name), scores in best_scores_ran.items():
        # Initialize if not already present
        if model_name not in best_rmse_scores:
            best_rmse_scores[model_name] = (scores['test_rmse'], pruner_name)
        if model_name not in best_corr_coef_scores:
            best_corr_coef_scores[model_name] = (scores['test_corr_coef'], pruner_name)

        # Update if better scores are found
        if scores['test_rmse'] < best_rmse_scores[model_name][0]:
            best_rmse_scores[model_name] = (scores['test_rmse'], pruner_name)
        if scores['test_corr_coef'] > best_corr_coef_scores[model_name][0]:
            best_corr_coef_scores[model_name] = (scores['test_corr_coef'], pruner_name)

    # Prepare data for plotting
    model_names_rmse = [f"{model} ({pruner})" for model, (rmse, pruner) in best_rmse_scores.items()]
    rmse_values = [rmse for rmse, _ in best_rmse_scores.values()]

    model_names_corr = [f"{model} ({pruner})" for model, (corr, pruner) in best_corr_coef_scores.items()]
    corr_values = [corr for corr, _ in best_corr_coef_scores.values()]

    # Plot RMSE
    plt.figure(figsize=(12, 6))
    bars_rmse = plt.bar(model_names_rmse, rmse_values, color='skyblue')

    # Highlight the best model
    best_rmse_index = np.argmin(rmse_values)
    bars_rmse[best_rmse_index].set_color('orange')

    # Annotate the bars with the RMSE scores
    for i, bar in enumerate(bars_rmse):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 0.05,
                 f'{rmse_values[i]:.5f}', ha='center', va='bottom', color='black')

    # Add labels and title for the RMSE bar chart
    plt.xlabel('Model (Pruner)')
    plt.ylabel('Test RMSE')
    plt.title('Best Test RMSE for Each Model')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    rmse_image_path = 'rmse_plot.png'
    _ensure_parent_dir(rmse_image_path)
    plt.savefig(_ensure_parent_dir(rmse_image_path))
    plt.close()

    # Plot Correlation Coefficient
    plt.figure(figsize=(12, 6))
    bars_corr = plt.bar(model_names_corr, corr_values, color='lightgreen')

    # Highlight the best model
    best_corr_index = np.argmax(corr_values)
    bars_corr[best_corr_index].set_color('orange')

    # Annotate the bars with the correlation coefficient scores
    for i, bar in enumerate(bars_corr):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 0.05,
                 f'{corr_values[i]:.5f}', ha='center', va='bottom', color='black')

    # Add labels and title for the correlation coefficient bar chart
    plt.xlabel('Model (Pruner)')
    plt.ylabel('Correlation Coefficient')
    plt.title('Best Correlation Coefficient for Each Model')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    corr_image_path = 'corr_plot.png'
    _ensure_parent_dir(corr_image_path)
    plt.savefig(_ensure_parent_dir(corr_image_path))
    plt.close()

    # Load the existing Excel file
    workbook = load_workbook(_ensure_excel_file(excel_file_path))

    # Create a new sheet for the plots
    sheet_name = 'Best Models Plots'
    if sheet_name in workbook.sheetnames:
        sheet = workbook[sheet_name]
    else:
        sheet = workbook.create_sheet(title=sheet_name)

    # Insert images into the new Excel sheet
    img_rmse = Image(rmse_image_path)
    img_corr = Image(corr_image_path)

    # Insert images
    sheet.add_image(img_rmse, 'A1')
    sheet.add_image(img_corr, 'A20')  # Adjust the position as needed

    # Save the workbook
    _ensure_parent_dir(excel_file_path)
    workbook.save(_ensure_parent_dir(excel_file_path))

    # Clean up the image files
    if os.path.exists(str(rmse_image_path)): os.remove(str(rmse_image_path))
    if os.path.exists(str(corr_image_path)): os.remove(str(corr_image_path))

# Example usage
# plot_best_scores(best_scores_ran, 'path_to_your_excel_file.xlsx')

# %%
import os

def _ensure_parent_dir(path):
    parent = os.path.dirname(path)
    if parent:
        os.makedirs(parent, exist_ok=True)
    return path

import os
def generate_interpretml_explanations_summary_pruners(
    results_dict, X_train, y_train, X_test, feature_names, instance_indices=None, excel_file_path=None
):
    if instance_indices is None:
        instance_indices = range(len(X_test))
    elif isinstance(instance_indices, int):
        instance_indices = [instance_indices]

    valid_indices = [idx for idx in instance_indices if 0 <= idx < len(X_test)]
    if not valid_indices:
        print("No valid instance indices provided.")
        return

    if isinstance(X_test, pd.DataFrame):
        instances_to_explain = X_test.iloc[valid_indices]
    else:
        instances_to_explain = X_test[valid_indices]

    best_model_pruners = {}
    for model_key, model_info in results_dict.items():
        if isinstance(model_key, tuple):
            model_name, pruner_name = model_key
        else:
            model_name = model_key
            pruner_name = None

        best_score = model_info.get('best_score')
        if best_score is None:
            print(f"No 'best_score' found for {model_key}. Skipping this combination.")
            continue

        if model_name not in best_model_pruners:
            best_model_pruners[model_name] = {
                'pruner_name': pruner_name,
                'model_info': model_info,
                'best_score': best_score
            }
        else:
            current_best_score = best_model_pruners[model_name]['best_score']
            if best_score < current_best_score:
                best_model_pruners[model_name] = {
                    'pruner_name': pruner_name,
                    'model_info': model_info,
                    'best_score': best_score
                }

    for model_name, info in best_model_pruners.items():
        pruner_name = info['pruner_name']
        model_info = info['model_info']
        best_params = dict(model_info['best_params'])  # don't mutate original!
        model_class = model_classes.get(model_name)

        if model_class is None:
            print(f"Model {model_name} is not supported or not available.")
            continue

        if model_name == 'CatBoost':
            best_params['verbose'] = 0

        # ------- Main model fit logic ---------
        if model_name == "TabNet":
            # TabNet: reshape y, fit, flatten pred for LIME/SHAP, etc.
            y_train_tabnet = np.array(y_train).reshape(-1, 1)
            try:
                model = model_class(**{k: v for k, v in best_params.items() if k != "verbose"})
            except TypeError:
                model = model_class()
            model.fit(np.array(X_train), y_train_tabnet, max_epochs=100, patience=10, batch_size=1024, eval_set=[(np.array(X_train), y_train_tabnet)])
            def predict_fn(data):
                preds = model.predict(np.array(data))
                # flatten for interpreters
                return preds.flatten()
        else:
            try:
                model = model_class(**best_params)
            except TypeError:
                model = model_class()
            model.fit(X_train, y_train)
            def predict_fn(data):
                return model.predict(data)

        if isinstance(X_train, pd.DataFrame):
            data_for_explainer = X_train.values
        else:
            data_for_explainer = X_train

        if isinstance(instances_to_explain, pd.DataFrame):
            data_for_explanation = instances_to_explain.values
        else:
            data_for_explanation = instances_to_explain

        # Generate LIME explanations
        lime_explainer = LimeTabular(
            predict_fn,
            data=data_for_explainer,
            feature_names=feature_names,
            random_state=1,
            mode='regression'
        )
        lime_explanation = lime_explainer.explain_local(data_for_explanation)

        feature_importances_lime = {}
        num_instances = len(valid_indices)
        for idx in range(num_instances):
            explanation = lime_explanation.data(idx)
            for feature_name, feature_score in zip(explanation['names'], explanation['scores']):
                feature_importances_lime[feature_name] = feature_importances_lime.get(feature_name, 0) + abs(feature_score)
        feature_importances_lime = {k: v / num_instances for k, v in feature_importances_lime.items()}
        feature_importances_lime = {k: round(v, 3) for k, v in feature_importances_lime.items()}

        # Generate SHAP explanations using ShapKernel
        try:
            shap_explainer = ShapKernel(predict_fn, data_for_explainer, feature_names=feature_names)
            shap_explanation = shap_explainer.explain_local(data_for_explanation)

            feature_importances_shap = {}
            for idx in range(num_instances):
                explanation = shap_explanation.data(idx)
                for feature_name, feature_score in zip(explanation['names'], explanation['scores']):
                    feature_importances_shap[feature_name] = feature_importances_shap.get(feature_name, 0) + abs(feature_score)

            feature_importances_shap = {k: v / num_instances for k, v in feature_importances_shap.items()}
            feature_importances_shap = {k: round(v, 3) for k, v in feature_importances_shap.items()}
        except Exception as e:
            print(f"Could not compute SHAP values for model {model_name}: {e}")
            feature_importances_shap = {}

        # Plot LIME and SHAP feature importances side by side
        fig, axes = plt.subplots(1, 2, figsize=(34, 36))

        # Plot LIME feature importances
        lime_importances_df = pd.DataFrame.from_dict(
            feature_importances_lime, orient='index', columns=['importance']
        )
        lime_importances_df.sort_values(by='importance', ascending=False, inplace=True)
        lime_importances_df.plot(kind='bar', legend=False, color='skyblue', ax=axes[0])
        axes[0].set_title(f"LIME Feature Importances for {model_name}")
        axes[0].set_ylabel("Average Absolute Importance Score")
        axes[0].set_xlabel("Features")
        axes[0].tick_params(axis='x', rotation=45)

        for p in axes[0].patches:
            height = p.get_height()
            axes[0].annotate(f'{height:.3f}',
                             (p.get_x() + p.get_width() / 2., height),
                             ha='center', va='bottom', fontsize=8)

        # Plot SHAP feature importances
        shap_importances_df = pd.DataFrame.from_dict(
            feature_importances_shap, orient='index', columns=['importance']
        )
        shap_importances_df.sort_values(by='importance', ascending=False, inplace=True)
        shap_importances_df.plot(kind='bar', legend=False, color='orange', ax=axes[1])
        axes[1].set_title(f"SHAP Feature Importances for {model_name}")
        axes[1].set_ylabel("Average Absolute SHAP Value")
        axes[1].set_xlabel("Features")
        axes[1].tick_params(axis='x', rotation=45)

        for p in axes[1].patches:
            height = p.get_height()
            axes[1].annotate(f'{height:.3f}',
                             (p.get_x() + p.get_width() / 2., height),
                             ha='center', va='bottom', fontsize=8)

        plt.tight_layout()

        # Save plots as images
        image_path = f'feature_importances_{model_name}.png'
        fig.savefig(_ensure_parent_dir(image_path))
        plt.close(fig)

        # Optionally insert images and scores into an Excel file
        if excel_file_path:
            workbook = load_workbook(_ensure_excel_file(excel_file_path))
            sheet_name = f'{model_name} Explanations'
            if sheet_name in workbook.sheetnames:
                sheet = workbook[sheet_name]
            else:
                sheet = workbook.create_sheet(title=sheet_name)

            # Insert images into the new Excel sheet
            img = Image(image_path)
            sheet.add_image(img, 'A1')

            # Create a new sheet for feature importance scores
            scores_sheet_name = f'{model_name} Scores'
            if scores_sheet_name in workbook.sheetnames:
                scores_sheet = workbook[scores_sheet_name]
            else:
                scores_sheet = workbook.create_sheet(title=scores_sheet_name)

            # Write LIME scores
            scores_sheet.append(['Feature', 'LIME Importance'])
            for feature, importance in feature_importances_lime.items():
                scores_sheet.append([feature, importance])

            # Write SHAP scores if available
            if feature_importances_shap:
                scores_sheet.append(['Feature', 'SHAP Importance'])
                for feature, importance in feature_importances_shap.items():
                    scores_sheet.append([feature, importance])

            # Save the workbook
            _ensure_parent_dir(excel_file_path)
            workbook.save(_ensure_parent_dir(excel_file_path))

            # Clean up the image file
            if os.path.exists(str(image_path)): os.remove(str(image_path))

# %% [markdown]
# # **Hyperparameter tuning using Autosampler by Optuna**

# %%
import os

def _ensure_parent_dir(path):
    parent = os.path.dirname(path)
    if parent:
        os.makedirs(parent, exist_ok=True)
    return path

import os
import joblib

def mseloss_objective(yhat, y, sample_weight=None):
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    gradient = yhat - y
    hessian = torch.ones_like(yhat)
    return gradient, hessian


def rmseloss_metric(yhat, y, sample_weight=None):
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    loss = torch.sqrt(torch.mean((yhat - y) ** 2))
    return loss


def hyperparameter_tuning_all(X_train, y_train, X_test, y_test, excel_path):

    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    # ================= NEW =================
    model_save_dir = "./drive/MyDrive/water_quality_wqi_uncertainty_analysis/hyperparameter_tuning/models"
    os.makedirs(model_save_dir, exist_ok=True)
    best_rmse_tracker = {}
    # =======================================

    models = {
        'Random Forest': (RandomForestRegressor, {
            'n_estimators': [100, 200, 300, 500, 700],
            'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
            'max_depth': [None, 10, 20, 30, 40],
            'min_samples_split': [2, 5, 10, 0.01],
            'min_samples_leaf': [1, 3, 5, 0.01],
            'min_weight_fraction_leaf': [0.0, 0.01, 0.1, 0.2],
            'max_features': [1.0, 'sqrt', 'log2', 0.3, 0.5],
            'max_leaf_nodes': [None, 50, 100, 200],
            'min_impurity_decrease': [0.0, 0.01, 0.1, 0.2],
            'n_jobs': [-1],
            'random_state': [42],
            'verbose': [0],
            'warm_start': [False],
            'ccp_alpha': [0.0, 0.001, 0.01, 0.05, 0.1]
        }),
        'Gradient Boosting': (GradientBoostingRegressor, {
            'loss': ['squared_error', 'absolute_error', 'huber', 'quantile'],
            'learning_rate': [0.01, 0.05, 0.1, 0.2],
            'n_estimators': [100, 200, 300, 500, 700],
            'subsample': [1.0, 0.9, 0.7, 0.5],
            'criterion': ['friedman_mse', 'squared_error'],
            'min_samples_split': [2, 5, 10, 0.01],
            'min_samples_leaf': [1, 3, 5, 0.01],
            'min_weight_fraction_leaf': [0.0, 0.01, 0.05, 0.1],
            'max_depth': [3, 5, 7, 10],
            'min_impurity_decrease': [0.0, 0.01, 0.1],
            'init': [None],
            'random_state': [42],
            'max_features': [None, 'sqrt', 'log2', 0.5],
            'alpha': [0.9, 0.5, 0.1],
            'verbose': [0],
            'max_leaf_nodes': [None, 10, 30, 50],
            'warm_start': [False],
            'validation_fraction': [0.1],
            'n_iter_no_change': [None, 10, 20],
            'tol': [1e-4, 1e-3],
            'ccp_alpha': [0.0, 0.001, 0.01]
        }),
        'XGBoost': (XGBRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7],
            'min_child_weight': [1, 3, 5],
            'gamma': [0, 0.1, 0.5, 1],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9],
            'colsample_bytree': [0.5, 0.7, 0.9],
            'colsample_bylevel': [0.5, 0.7, 0.9],
            'reg_alpha': [0, 0.01, 0.1, 1],
            'reg_lambda': [0.1, 1, 5, 10],
            'objective': ['reg:squarederror'],
            'random_state': [42],
            'n_jobs': [-1]
        }),
        'LightGBM': (LGBMRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'num_leaves': [15, 31, 63],
            'max_depth': [3, 5, 7, -1],
            'min_child_samples': [1, 5, 10, 20],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
            'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
            'reg_alpha': [0, 0.01, 0.1, 1],
            'reg_lambda': [0, 0.1, 1, 10],
            'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1],
            'bagging_freq': [0, 1, 5],
            'objective': ['regression'],
            'random_state': [42],
            'n_jobs': [-1],
            'verbose': [-1]
        }),
        'GPBoost': (GPBoostRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7, -1],
            'num_leaves': [15, 31, 63],
            'min_child_samples': [1, 5, 10, 20],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
            'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
            'reg_alpha': [0, 0.1, 0.5, 1.0],
            'reg_lambda': [0, 0.1, 0.5, 1.0],
            'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1],
            'random_state': [42],
            'n_jobs': [-1],
            'verbose': [-1]
        }),
        'CatBoost': (CatBoostRegressor, {
            'iterations': [200, 500, 1000],
            'learning_rate': [0.01, 0.03, 0.05, 0.1],
            'depth': [4, 6, 8, 10],
            'l2_leaf_reg': [1, 3, 5, 7, 9],
            'border_count': [32, 64, 128],
            'min_data_in_leaf': [1, 5, 10, 20],
            'rsm': [0.6, 0.8, 1.0],
            'bagging_temperature': [0, 1, 10],
            'random_seed': [42],
            'verbose': [0]
        }),
        'NGBoost': (NGBRegressor, {
            'n_estimators': [200, 500, 1000],
            'learning_rate': [0.01, 0.03, 0.05, 0.1],
            'natural_gradient': [True, False],
            'minibatch_frac': [0.5, 0.7, 0.9, 1.0],
            'col_sample': [0.5, 0.7, 0.9, 1.0],
            'Dist': [Normal],
            'Score': [LogScore],
            'random_state': [42],
            'verbose': [0]
        }),
        'TabNet': (TabNetRegressor, {
            'n_d': [8, 16, 32, 64],
            'n_a': [8, 16, 32, 64],
            'n_steps': [3, 5, 7, 10],
            'gamma': [1.0, 1.3, 1.5, 2.0],
            'lambda_sparse': [1e-4, 1e-3, 1e-2],
            'optimizer_params': [{'lr': 2e-2}], # Fixed learning rate as recommended
            'mask_type': ['sparsemax', 'entmax'],
            'n_shared': [1, 2, 3],
            'n_independent': [1, 2, 3],
            'scheduler_params': [{"step_size": 10, "gamma": 0.9}],
            'scheduler_fn': [torch.optim.lr_scheduler.StepLR],
            'seed': [42],
            'verbose': [0]
        }),
        'HistGradientBoosting': (HistGradientBoostingRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_iter': [100, 200, 300, 400, 500],
            'max_depth': [3, 5, 7, None],
            'min_samples_leaf': [5, 10, 20],
            'max_leaf_nodes': [15, 31, 63, None],
            'l2_regularization': [0.0, 0.1, 0.5, 1.0],
            'max_bins': [64, 128, 255],
            'early_stopping': [True, False],
            'validation_fraction': [0.1, 0.2],
            'n_iter_no_change': [5, 10, 15],
            'loss': ['squared_error'],
            'random_state': [42],
            'verbose': [0]
        }),
        'PGBM': (PGBM, {})
    }

    pruners = [
        optuna.pruners.MedianPruner(),
        optuna.pruners.NopPruner(),
        optuna.pruners.PatientPruner(optuna.pruners.MedianPruner(), patience=3),
        optuna.pruners.PercentilePruner(25.0),
        optuna.pruners.SuccessiveHalvingPruner(),
        optuna.pruners.HyperbandPruner(),
        optuna.pruners.ThresholdPruner(lower=0.1),
        optuna.pruners.WilcoxonPruner()
    ]

    best_scores = {}
    predictions_df = pd.DataFrame({'Actual': y_test})
    timing_records = []

    for model_name, (model_class, param_space) in models.items():

        rmse_trial_history = {p.__class__.__name__: [] for p in pruners}

        for pruner in pruners:
            pruner_name = pruner.__class__.__name__
            print(f"Running Optuna for {model_name} with {pruner_name}...")
            start_time = time.time()

            best_rmse_tracker[(model_name, pruner_name)] = np.inf

            sampler = optunahub.load_module("samplers/auto_sampler").AutoSampler()
            study = optuna.create_study(direction='minimize', sampler=sampler, pruner=pruner)

            if model_name == 'PGBM':

                def pgbm_objective(trial):
                    params = {
                            'n_estimators': trial.suggest_categorical('n_estimators', [100, 200, 300, 500]),
                            'learning_rate': trial.suggest_categorical('learning_rate', [0.01, 0.05, 0.1, 0.15]),
                            'max_leaves': trial.suggest_int('max_leaves', 15, 63),
                            'min_split_gain': trial.suggest_categorical('min_split_gain', [0.0, 0.1, 0.5, 1.0]),
                            'reg_lambda': trial.suggest_categorical('reg_lambda', [0.1, 1.0, 5.0, 10.0]),
                            'feature_fraction': trial.suggest_categorical('feature_fraction', [0.5, 0.7, 0.9, 1.0]),
                            'bagging_fraction': trial.suggest_categorical('bagging_fraction', [0.5, 0.7, 0.9, 1.0]),
                            'tree_correlation': trial.suggest_categorical('tree_correlation', [0.0, 0.1, 0.2, 0.3]),
                            'min_data_in_leaf': trial.suggest_categorical('min_data_in_leaf', [3, 5, 10, 20]),
                            'max_bin': trial.suggest_categorical('max_bin', [64, 128, 256]),
                            'distribution': trial.suggest_categorical('distribution', ['normal', 'studentt', 'laplace']),
                            'objective': 'mse',
                            'metric': 'rmse',
                            'random_state': 42,
                            'verbose': 0
                        }

                    model = PGBM()
                    model.train((X_train, y_train),
                                objective=mseloss_objective,
                                metric=rmseloss_metric,
                                params=params)

                    y_pred = model.predict(X_test)
                    mse = mean_squared_error(y_test, y_pred)
                    rmse = np.sqrt(mse)

                    rmse_trial_history[pruner_name].append(rmse)

                    # ===== SAVE BEST MODEL =====
                    if rmse < best_rmse_tracker[(model_name, pruner_name)]:
                        best_rmse_tracker[(model_name, pruner_name)] = rmse
                        save_path = os.path.join(
                            model_save_dir,
                            f"{model_name}_{pruner_name}_BEST.pkl"
                        )
                        _ensure_parent_dir(save_path)
                        joblib.dump(model, _ensure_parent_dir(save_path))

                    return mse

                study.optimize(pgbm_objective, n_trials=50)

            else:

                def objective(trial):
                    params = {}
                    for key, values in param_space.items():
                        params[key] = trial.suggest_categorical(key, values)

                    model = model_class(**params)

                    if model_name == 'TabNet':
                        model.fit(X_train, y_train.reshape(-1, 1))
                    else:
                        model.fit(X_train, y_train)


                    y_pred = model.predict(X_test)

                    if model_name == 'TabNet':
                        y_pred = y_pred.ravel()

                    mse = mean_squared_error(y_test, y_pred)

                    rmse = np.sqrt(mse)

                    rmse_trial_history[pruner_name].append(rmse)

                    # ===== SAVE BEST MODEL =====
                    if rmse < best_rmse_tracker[(model_name, pruner_name)]:
                        best_rmse_tracker[(model_name, pruner_name)] = rmse
                        save_path = os.path.join(
                            model_save_dir,
                            f"{model_name}_{pruner_name}_BEST.pkl"
                        )
                        _ensure_parent_dir(save_path)
                        joblib.dump(model, _ensure_parent_dir(save_path))

                    return mse

                study.optimize(objective, n_trials=50)

            elapsed_time = time.time() - start_time

            # Load frozen model (NO RETRAIN)
            best_model = joblib.load(
                os.path.join(model_save_dir, f"{model_name}_{pruner_name}_BEST.pkl")
            )

            y_pred = best_model.predict(X_test)

            if model_name == 'TabNet':
                y_pred = y_pred.ravel()

            mse = mean_squared_error(y_test, y_pred)
            rmse = np.sqrt(mse)
            corr_coef = np.corrcoef(y_test, y_pred)[0, 1]


            predictions_df[f'{model_name}_{pruner_name}_Predicted'] = y_pred

            best_scores[(model_name, pruner_name)] = {
                'best_score': mse,
                'best_params': study.best_params,
                'test_mse': mse,
                'test_rmse': rmse,
                'test_corr_coef': corr_coef,
                'pruner': pruner_name
            }

            timing_records.append({
                'Model': model_name,
                'Pruner': pruner_name,
                'Tuning_Time_Seconds': elapsed_time
            })

        # RMSE plots & Excel writing (UNCHANGED)
        rmse_df = pd.DataFrame(rmse_trial_history)
        rmse_df.insert(0, "Trial", np.arange(1, len(rmse_df) + 1))

        if not os.path.exists(excel_path):
            pd.DataFrame().to_excel(excel_path)
        with pd.ExcelWriter(_ensure_parent_dir(_ensure_excel_file(excel_path)), engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
            writer
            rmse_df.to_excel(writer, sheet_name=f"RMSE_Trials_{model_name}", index=False)
        # ================= SAVE RMSE PLOT =================
        plot_dir = os.path.dirname(excel_path)
        plot_path = os.path.join(plot_dir, f"RMSE_Trials_{model_name}.png")

        plt.figure(figsize=(10, 6))
        for pruner_name, values in rmse_trial_history.items():
            if len(values) > 0:   # <-- important safety check
                plt.plot(values, label=pruner_name, linewidth=2)

        plt.title(f"RMSE Variation Over Trials\n{model_name}")
        plt.xlabel("Trial Number")
        plt.ylabel("RMSE")
        plt.legend(loc="center left", bbox_to_anchor=(1.02, 0.5))
        plt.tight_layout()

        _ensure_parent_dir(plot_path)
        plt.savefig(_ensure_parent_dir(plot_path), dpi=100, bbox_inches="tight")
        plt.close()

        # ================= INSERT PLOT INTO EXCEL =================
        wb = load_workbook(_ensure_excel_file(excel_path))
        ws = wb[f"RMSE_Trials_{model_name}"]

        img = Image(plot_path)
        img.anchor = "J2"
        ws.add_image(img)

        _ensure_parent_dir(excel_path)
        wb.save(_ensure_parent_dir(excel_path))

    timing_df = pd.DataFrame(timing_records)

    if not os.path.exists(excel_path):
        pd.DataFrame().to_excel(excel_path)
    with pd.ExcelWriter(_ensure_parent_dir(_ensure_excel_file(excel_path)), engine='openpyxl', mode='a') as writer:
        writer
        predictions_df.to_excel(writer, sheet_name='Predictions', index=False)
        writer
        timing_df.to_excel(writer, sheet_name='Tuning_Time', index=False)

    return best_scores


best_scores_autosampler = hyperparameter_tuning_all(X_train, y_train, X_test, y_test, "./drive/MyDrive/water_quality_wqi_uncertainty_analysis/hyperparameter_tuning/test.xlsx")
# Out:
# Running Optuna for Random Forest with MedianPruner...
# [I 2026-05-05 02:31:39,023] A new study created in memory with name: no-name-86013f45-0079-4696-bb3c-2ca531e98912
# [I 2026-05-05 02:31:44,054] Trial 0 finished with value: 1854.615371342262 and parameters: {'n_estimators': 500, 'criterion': 'poisson', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.1, 'max_features': 1.0, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 0 with value: 1854.615371342262.
# [I 2026-05-05 02:31:44,924] Trial 1 finished with value: 1707.8628302488364 and parameters: {'n_estimators': 100, 'criterion': 'poisson', 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.1, 'max_features': 0.5, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 1 with value: 1707.8628302488364.
# [I 2026-05-05 02:31:52,106] Trial 2 finished with value: 2355.408806121951 and parameters: {'n_estimators': 500, 'criterion': 'absolute_error', 'max_depth': 40, 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.2, 'max_features': 1.0, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 1 with value: 1707.8628302488364.
# [I 2026-05-05 02:31:52,809] Trial 3 finished with value: 1681.4764868102197 and parameters: {'n_estimators': 100, 'criterion': 'squared_error', 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.1, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 3 with value: 1681.4764868102197.
# [I 2026-05-05 02:31:53,272] Trial 4 finished with value: 1785.6261870665107 and parameters: {'n_estimators': 200, 'criterion': 'poisson', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.1, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 3 with value: 1681.4764868102197.
# [I 2026-05-05 02:31:54,628] Trial 5 finished with value: 1219.6379125538642 and parameters: {'n_estimators': 300, 'criterion': 'poisson', 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.3, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 5 with value: 1219.6379125538642.
# [I 2026-05-05 02:31:58,733] Trial 6 finished with value: 2641.50252132867 and parameters: {'n_estimators': 500, 'criterion': 'poisson', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.2, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 5 with value: 1219.6379125538642.
# [I 2026-05-05 02:32:02,432] Trial 7 finished with value: 1173.7166455824824 and parameters: {'n_estimators': 500, 'criterion': 'friedman_mse', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.5, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 7 with value: 1173.7166455824824.
# [I 2026-05-05 02:32:04,781] Trial 8 finished with value: 3182.9085121013704 and parameters: {'n_estimators': 500, 'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.2, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 7 with value: 1173.7166455824824.
# [I 2026-05-05 02:32:05,126] Trial 9 finished with value: 1027.2163239396423 and parameters: {'n_estimators': 100, 'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 9 with value: 1027.2163239396423.
# [I 2026-05-05 02:32:05,388] Trial 10 finished with value: 1067.546843890179 and parameters: {'n_estimators': 100, 'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 9 with value: 1027.2163239396423.
# [I 2026-05-05 02:32:06,167] Trial 11 finished with value: 1044.1099765348638 and parameters: {'n_estimators': 300, 'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 9 with value: 1027.2163239396423.
# [I 2026-05-05 02:32:06,867] Trial 12 finished with value: 1001.4853576234293 and parameters: {'n_estimators': 100, 'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 12 with value: 1001.4853576234293.
# [I 2026-05-05 02:32:07,527] Trial 13 finished with value: 1003.4162107818296 and parameters: {'n_estimators': 100, 'criterion': 'friedman_mse', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 12 with value: 1001.4853576234293.
# [I 2026-05-05 02:32:08,157] Trial 14 finished with value: 1203.4473604241302 and parameters: {'n_estimators': 100, 'criterion': 'poisson', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 12 with value: 1001.4853576234293.
# [I 2026-05-05 02:32:08,494] Trial 15 finished with value: 2817.560432777601 and parameters: {'n_estimators': 100, 'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.2, 'max_features': 0.5, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 12 with value: 1001.4853576234293.
# [I 2026-05-05 02:32:15,009] Trial 16 finished with value: 971.9879537682887 and parameters: {'n_estimators': 700, 'criterion': 'friedman_mse', 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 16 with value: 971.9879537682887.
# [I 2026-05-05 02:32

#    'criterion': 'squared_error',
#    'min_samples_split': 2,
#    'min_samples_leaf': 3,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 3,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'log2',
#    'alpha': 0.5,
#    'verbose': 0,
#    'max_leaf_nodes': 50,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.001,
#    'ccp_alpha': 0.01},
#   'test_mse': 754.0504180723915,
#   'test_rmse': 27.459978479095565,
#   'test_corr_coef': 0.9362645279730918,
#   'pruner': 'MedianPruner'},
#  ('Gradient Boosting', 'NopPruner'): {'best_score': 761.0435920792785,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 300,
#    'subsample': 0.5,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 10,
#    'min_impurity_decrease': 0.01,
#    'init': None,
#    'random_state': 42,
#    'max_features': None,
#    'alpha': 0.5,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 10,
#    'tol': 0.001,
#    'ccp_alpha': 0.001},
#   'test_mse': 761.0435920792785,
#   'test_rmse': 27.587018542772586,
#   'test_corr_coef': 0.9464392555609986,
#   'pruner': 'NopPruner'},
#  ('Gradient Boosting', 'PatientPruner'): {'best_score': 744.3747237829126,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.2,
#    'n_estimators': 700,
#    'subsample': 0.5,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 2,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 10,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 10,
#    'tol': 0.0001,
#    'ccp_alpha': 0.01},
#   'test_mse': 744.3747237829126,
#   'test_rmse': 27.283231549486814,
#   'test_corr_coef': 0.940474271213905,
#   'pruner': 'PatientPruner'},
#  ('Gradient Boosting', 'PercentilePruner'): {'best_score': 716.3070812349041,
#   'best_params': {'loss': 'absolute_error',
#    'learning_rate': 0.05,
#    'n_estimators': 700,
#    'subsample': 0.7,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 3,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.1,
#    'verbose': 0,
#    'max_leaf_nodes': None,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.001,
#    'ccp_alpha': 0.0},
#   'test_mse': 716.3070812349041,
#   'test_rmse': 26.763913787690022,
#   'test_corr_coef': 0.9451671251865507,
#   'pruner': 'PercentilePruner'},
#  ('Gradient Boosting',
#   'SuccessiveHalvingPruner'): {'best_score': 716.5887735253378, 'best_params': {'loss': 'huber',
#    'learning_rate': 0.2,
#    'n_estimators': 300,
#    'subsample': 0.5,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 3,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': 10,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.001,
#    'ccp_alpha': 0.001}, 'test_mse': 716.5887735253378, 'test_rmse': 26.769175809601197, 'test_corr_coef': 0.9460756387352265, 'pruner': 'SuccessiveHalvingPruner'},
#  ('Gradient Boosting', 'HyperbandPruner'): {'best_score': 835.4739204988285,
#   'best_params': {'loss': 'huber',
#    'learning_rate': 0.1,
#    'n_estimators': 700,
#    'subsample': 0.5,
#    'criterion': 'squared_error',
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.05,
#    'max_depth': 3,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'sqrt',
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': None,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 20,
#    'tol': 0.001,
#    'ccp_alpha': 0.01},
#   'test_mse': 835.4739204988285,
#   'test_rmse': 28.904565737938853,
#   'test_corr_coef': 0.9217567825696178,
#   'pruner': 'HyperbandPruner'},
#  ('Gradient Boosting', 'ThresholdPruner'): {'best_score': 662.459950007907,
#   'best_params': {'loss': 'absolute_error',
#    'learning_rate': 0.2,
#    'n_estimators': 300,
#    'subsample': 1.0,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 10,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.5,
#    'verbose': 0,
#    'max_leaf_nodes': 10,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.001},
#   'test_mse': 662.459950007907,
#   'test_rmse': 25.738297340886927,
#   'test_corr_coef': 0.9538979086193512,
#   'pruner': 'ThresholdPruner'},
#  ('Gradient Boosting', 'WilcoxonPruner'): {'best_score': 756.3554749979207,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 200,
#    'subsample': 0.5,
#    'criterion': 'squared_error',
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 5,
#    'min_impurity_decrease': 0.01,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 20,
#    'tol': 0.0001,
#    'ccp_alpha': 0.0},
#   'test_mse': 756.3554749979207,
#   'test_rmse': 27.501917660372715,
#   'test_corr_coef': 0.9416939437893872,
#   'pruner': 'WilcoxonPruner'},
#  ('XGBoost', 'MedianPruner'): {'best_score': 640.2401123046875,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'max_depth': 3,
#    'min_child_weight': 5,
#    'gamma': 0,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.9,
#    'reg_alpha': 1,
#    'reg_lambda': 0.1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 640.2401123046875,
#   'test_rmse': 25.30296647242547,
#   'test_corr_coef': 0.9493477503198916,
#   'pruner': 'MedianPruner'},
#  ('XGBoost', 'NopPruner'): {'best_score': 610.7496948242188,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'min_child_weight': 3,
#    'gamma': 0.1,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 0.1,
#    'reg_lambda': 5,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 610.7496948242188,
#   'test_rmse': 24.713350538205432,
#   'test_corr_coef': 0.9507640415112198,
#   'pruner': 'NopPruner'},
#  ('XGBoost', 'PatientPruner'): {'best_score': 631.3193359375,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'max_depth': 3,
#    'min_child_weight': 3,
#    'gamma': 1,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 0.01,
#    'reg_lambda': 10,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 631.3193359375,
#   'test_rmse': 25.12606885164291,
#   'test_corr_coef': 0.9484476112216284,
#   'pruner': 'PatientPruner'},
#  ('XGBoost', 'PercentilePruner'): {'best_score': 675.7360229492188,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'max_depth': 5,
#    'min_child_weight': 5,
#    'gamma': 0.5,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.9,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 675.7360229492188,
#   'test_rmse': 25.994923022567672,
#   'test_corr_coef': 0.9469671543154728,
#   'pruner': 'PercentilePruner'},
#  ('XGBoost', 'SuccessiveHalvingPruner'): {'best_score': 659.9248046875,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.1,
#    'max_depth': 5,
#    'min_child_weight': 3,
#    'gamma': 1,
#    'subsample': 0.6,
#    'colsample_bytree': 0.5,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 1,
#    'reg_lambda': 5,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 659.9248046875,
#   'test_rmse': 25.689001628858605,
#   'test_corr_coef': 0.9456009946223333,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('XGBoost', 'HyperbandPruner'): {'best_score': 612.9705810546875,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.05,
#    'max_depth': 5,
#    'min_child_weight': 1,
#    'gamma': 0,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 0.1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 612.9705810546875,
#   'test_rmse': 24.75824268914673,
#   'test_corr_coef': 0.9573288507168101,
#   'pruner': 'HyperbandPruner'},
#  ('XGBoost', 'ThresholdPruner'): {'best_score': 633.9602661132812,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 3,
#    'min_child_weight': 3,
#    'gamma': 0.1,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 1,
#    'reg_lambda': 10,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 633.9602661132812,
#   'test_rmse': 25.178567594549165,
#   'test_corr_coef': 0.9482371867264491,
#   'pruner': 'ThresholdPruner'},
#  ('XGBoost', 'WilcoxonPruner'): {'best_score': 580.662353515625,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'max_depth': 3,
#    'min_child_weight': 3,
#    'gamma': 1,
#    'subsample': 0.7,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 1,
#    'reg_lambda': 5,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 580.662353515625,
#   'test_rmse': 24.096936600232507,
#   'test_corr_coef': 0.956788176342319,
#   'pruner': 'WilcoxonPruner'},
#  ('LightGBM', 'MedianPruner'): {'best_score': 578.6019176710981,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'num_leaves': 15,
#    'max_depth': 3,
#    'min_child_samples': 5,
#    'subsample': 0.5,
#    'colsample_bytree': 0.5,
#    'reg_alpha': 0,
#    'reg_lambda': 1,
#    'min_child_weight': 0.1,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 578.6019176710981,
#   'test_rmse': 24.054145540241045,
#   'test_corr_coef': 0.9559617468827266,
#   'pruner': 'MedianPruner'},
#  ('LightGBM', 'NopPruner'): {'best_score': 572.9673527811109,
#   'best_params': {'n_estimators': 100,
#    'learning_rate': 0.15,
#    'num_leaves': 63,
#    'max_depth': -1,
#    'min_child_samples': 1,
#    'subsample': 0.5,
#    'colsample_bytree': 1.0,
#    'reg_alpha': 0,
#    'reg_lambda': 0,
#    'min_child_weight': 0.1,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 572.9673527811109,
#   'test_rmse': 23.936736468890466,
#   'test_corr_coef': 0.9611887987913483,
#   'pruner': 'NopPruner'},
#  ('LightGBM', 'PatientPruner'): {'best_score': 708.9731634033947,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'num_leaves': 63,
#    'max_depth': 5,
#    'min_child_samples': 20,
#    'subsample': 1.0,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.1,
#    'reg_lambda': 0.1,
#    'min_child_weight': 1e-05,
#    'bagging_freq': 0,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 708.9731634033947,
#   'test_rmse': 26.626549971849425,
#   'test_corr_coef': 0.9404266340021766,
#   'pruner': 'PatientPruner'},
#  ('LightGBM', 'PercentilePruner'): {'best_score': 609.126190708102,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.15,
#    'num_leaves': 15,
#    'max_depth': -1,
#    'min_child_samples': 5,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 1,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.01,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 609.126190708102,
#   'test_rmse': 24.680481978845187,
#   'test_corr_coef': 0.9510624432158318,
#   'pruner': 'PercentilePruner'},
#  ('LightGBM', 'SuccessiveHalvingPruner'): {'best_score': 717.8535623295816,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'num_leaves': 15,
#    'max_depth': -1,
#    'min_child_samples': 20,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.01,
#    'reg_lambda': 0,
#    'min_child_weight': 0.01,
#    'bagging_freq': 0,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 717.8535623295816,
#   'test_rmse': 26.79278937194822,
#   'test_corr_coef': 0.938322208058345,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('LightGBM', 'HyperbandPruner'): {'best_score': 666.0360274014204,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.1,
#    'num_leaves': 31,
#    'max_depth': -1,
#    'min_child_samples': 5,
#    'subsample': 0.6,
#    'colsample_bytree': 0.5,
#    'reg_alpha': 0,
#    'reg_lambda': 1,
#    'min_child_weight': 0.01,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 666.0360274014204,
#   'test_rmse': 25.807673808412495,
#   'test_corr_coef': 0.9507892886116864,
#   'pruner': 'HyperbandPruner'},
#  ('LightGBM', 'ThresholdPruner'): {'best_score': 747.4290721737005,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'num_leaves': 63,
#    'max_depth': 7,
#    'min_child_samples': 20,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 1,
#    'min_child_weight': 0.01,
#    'bagging_freq': 0,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 747.4290721737005,
#   'test_rmse': 27.339149075523558,
#   'test_corr_coef': 0.9390434541149658,
#   'pruner': 'ThresholdPruner'},
#  ('LightGBM', 'WilcoxonPruner'): {'best_score': 652.6185638820753,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'num_leaves': 15,
#    'max_depth': 5,
#    'min_child_samples': 5,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 1,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.1,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 652.6185638820753,
#   'test_rmse': 25.54640021376936,
#   'test_corr_coef': 0.9520011615689157,
#   'pruner': 'WilcoxonPruner'},
#  ('GPBoost', 'MedianPruner'): {'best_score': 739.4460646470335,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.1,
#    'max_depth': 7,
#    'num_leaves': 31,
#    'min_child_samples': 20,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 1.0,
#    'reg_lambda': 0.5,
#    'min_child_weight': 0.01,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 739.4460646470335,
#   'test_rmse': 27.19275757710191,
#   'test_corr_coef': 0.939276190627078,
#   'pruner': 'MedianPruner'},
#  ('GPBoost', 'NopPruner'): {'best_score': 769.7825420449794,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.05,
#    'max_depth': 5,
#    'num_leaves': 31,
#    'min_child_samples': 20,
#    'subsample': 0.8,
#    'colsample_bytree': 0.5,
#    'reg_alpha': 1.0,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.001,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 769.7825420449794,
#   'test_rmse': 27.744955253973277,
#   'test_corr_coef': 0.9341946617939768,
#   'pruner': 'NopPruner'},
#  ('GPBoost', 'PatientPruner'): {'best_score': 713.4071400441512,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'num_leaves': 63,
#    'min_child_samples': 20,
#    'subsample': 0.8,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.1,
#    'reg_lambda': 0,
#    'min_child_weight': 0.1,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 713.4071400441512,
#   'test_rmse': 26.709682514851263,
#   'test_corr_coef': 0.9393596679237969,
#   'pruner': 'PatientPruner'},
#  ('GPBoost', 'PercentilePruner'): {'best_score': 769.7424996833787,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'num_leaves': 15,
#    'min_child_samples': 20,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.5,
#    'reg_lambda': 1.0,
#    'min_child_weight': 0.01,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 769.7424996833787,
#   'test_rmse': 27.744233629411692,
#   'test_corr_coef': 0.935609752560284,
#   'pruner': 'PercentilePruner'},
#  ('GPBoost', 'SuccessiveHalvingPruner'): {'best_score': 761.7384223568865,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.1,
#    'max_depth': 3,
#    'num_leaves': 31,
#    'min_child_samples': 20,
#    'subsample': 1.0,
#    'colsample_bytree': 0.5,
#    'reg_alpha': 1.0,
#    'reg_lambda': 0.5,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 761.7384223568865,
#   'test_rmse': 27.59960909790004,
#   'test_corr_coef': 0.937832802625299,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('GPBoost', 'HyperbandPruner'): {'best_score': 724.9141691691829,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'max_depth': 5,
#    'num_leaves': 63,
#    'min_child_samples': 20,
#    'subsample': 0.8,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.5,
#    'reg_lambda': 0.1,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 724.9141691691829,
#   'test_rmse': 26.924230149981685,
#   'test_corr_coef': 0.9390675344312455,
#   'pruner': 'HyperbandPruner'},
#  ('GPBoost', 'ThresholdPruner'): {'best_score': 716.339492253343,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'num_leaves': 31,
#    'min_child_samples': 20,
#    'subsample': 0.5,
#    'colsample_bytree': 0.5,
#    'reg_alpha': 0.5,
#    'reg_lambda': 1.0,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 716.339492253343,
#   'test_rmse': 26.764519279324688,
#   'test_corr_coef': 0.9398871712481036,
#   'pruner': 'ThresholdPruner'},
#  ('GPBoost', 'WilcoxonPruner'): {'best_score': 700.9290174430228,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': -1,
#    'num_leaves': 63,
#    'min_child_samples': 20,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.5,
#    'reg_lambda': 0.5,
#    'min_child_weight': 0.1,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 700.9290174430228,
#   'test_rmse': 26.475064068723665,
#   'test_corr_coef': 0.941303497367147,
#   'pruner': 'WilcoxonPruner'},
#  ('CatBoost', 'MedianPruner'): {'best_score': 630.5453803317046,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.1,
#    'depth': 6,
#    'l2_leaf_reg': 1,
#    'border_count': 64,
#    'min_data_in_leaf': 10,
#    'rsm': 1.0,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 630.5453803317046,
#   'test_rmse': 25.11066268205012,
#   'test_corr_coef': 0.9489600108379744,
#   'pruner': 'MedianPruner'},
#  ('CatBoost', 'NopPruner'): {'best_score': 616.1908280836006,
#   'best_params': {'iterations': 500,
#    'learning_rate': 0.1,
#    'depth': 4,
#    'l2_leaf_reg': 1,
#    'border_count': 32,
#    'min_data_in_leaf': 10,
#    'rsm': 0.8,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 616.1908280836006,
#   'test_rmse': 24.823191335595844,
#   'test_corr_coef': 0.9520423604837481,
#   'pruner': 'NopPruner'},
#  ('CatBoost', 'PatientPruner'): {'best_score': 605.3897168900045,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.05,
#    'depth': 6,
#    'l2_leaf_reg': 1,
#    'border_count': 64,
#    'min_data_in_leaf': 5,
#    'rsm': 0.6,
#    'bagging_temperature': 10,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 605.3897168900045,
#   'test_rmse': 24.60466859947527,
#   'test_corr_coef': 0.9533736935494838,
#   'pruner': 'PatientPruner'},
#  ('CatBoost', 'PercentilePruner'): {'best_score': 605.3897168900045,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.05,
#    'depth': 6,
#    'l2_leaf_reg': 1,
#    'border_count': 64,
#    'min_data_in_leaf': 5,
#    'rsm': 0.6,
#    'bagging_temperature': 10,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 605.3897168900045,
#   'test_rmse': 24.60466859947527,
#   'test_corr_coef': 0.9533736935494838,
#   'pruner': 'PercentilePruner'},
#  ('CatBoost', 'SuccessiveHalvingPruner'): {'best_score': 673.3126355530995,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.05,
#    'depth': 6,
#    'l2_leaf_reg': 5,
#    'border_count': 128,
#    'min_data_in_leaf': 5,
#    'rsm': 0.6,
#    'bagging_temperature': 10,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 673.3126355530995,
#   'test_rmse': 25.948268449996803,
#   'test_corr_coef': 0.9500605148761747,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('CatBoost', 'HyperbandPruner'): {'best_score': 630.5453803317046,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.1,
#    'depth': 6,
#    'l2_leaf_reg': 1,
#    'border_count': 64,
#    'min_data_in_leaf': 10,
#    'rsm': 1.0,
#    'bagging_temperature': 10,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 630.5453803317046,
#   'test_rmse': 25.11066268205012,
#   'test_corr_coef': 0.9489600108379744,
#   'pruner': 'HyperbandPruner'},
#  ('CatBoost', 'ThresholdPruner'): {'best_score': 666.1882601036941,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.1,
#    'depth': 8,
#    'l2_leaf_reg': 5,
#    'border_count': 128,
#    'min_data_in_leaf': 1,
#    'rsm': 1.0,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 666.1882601036941,
#   'test_rmse': 25.810623008825146,
#   'test_corr_coef': 0.950099905571765,
#   'pruner': 'ThresholdPruner'},
#  ('CatBoost', 'WilcoxonPruner'): {'best_score': 630.5453803317046,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.1,
#    'depth': 6,
#    'l2_leaf_reg': 1,
#    'border_count': 64,
#    'min_data_in_leaf': 10,
#    'rsm': 1.0,
#    'bagging_temperature': 0,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 630.5453803317046,
#   'test_rmse': 25.11066268205012,
#   'test_corr_coef': 0.9489600108379744,
#   'pruner': 'WilcoxonPruner'},
#  ('NGBoost', 'MedianPruner'): {'best_score': 633.7883371611798,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.05,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.5,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 633.7883371611798,
#   'test_rmse': 25.17515317056045,
#   'test_corr_coef': 0.9537348576134478,
#   'pruner': 'MedianPruner'},
#  ('NGBoost', 'NopPruner'): {'best_score': 625.8651941922564,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.05,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.9,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 625.8651941922564,
#   'test_rmse': 25.017297899498587,
#   'test_corr_coef': 0.9567018889243485,
#   'pruner': 'NopPruner'},
#  ('NGBoost', 'PatientPruner'): {'best_score': 614.3586176821068,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.05,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.7,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 614.3586176821068,
#   'test_rmse': 24.786258646316647,
#   'test_corr_coef': 0.9577743557511592,
#   'pruner': 'PatientPruner'},
#  ('NGBoost', 'PercentilePruner'): {'best_score': 590.5933340686115,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.05,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.7,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 590.5933340686115,
#   'test_rmse': 24.302126122391257,
#   'test_corr_coef': 0.9607331309182398,
#   'pruner': 'PercentilePruner'},
#  ('NGBoost', 'SuccessiveHalvingPruner'): {'best_score': 606.5892344399286,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.03,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.9,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 606.5892344399286,
#   'test_rmse': 24.629032348834347,
#   'test_corr_coef': 0.9609250750388171,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('NGBoost', 'HyperbandPruner'): {'best_score': 635.8872851948404,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.03,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.5,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 635.8872851948404,
#   'test_rmse': 25.21680561044242,
#   'test_corr_coef': 0.955047856253273,
#   'pruner': 'HyperbandPruner'},
#  ('NGBoost', 'ThresholdPruner'): {'best_score': 630.5282162944842,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.05,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.9,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 630.5282162944842,
#   'test_rmse': 25.110320911817997,
#   'test_corr_coef': 0.9599234408389603,
#   'pruner': 'ThresholdPruner'},
#  ('NGBoost', 'WilcoxonPruner'): {'best_score': 600.343415457771,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.1,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.9,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 600.343415457771,
#   'test_rmse': 24.501906363745885,
#   'test_corr_coef': 0.9604592115918422,
#   'pruner': 'WilcoxonPruner'},
#  ('TabNet', 'MedianPruner'): {'best_score': 721.5196533203125,
#   'best_params': {'n_d': 64,
#    'n_a': 16,
#    'n_steps': 5,
#    'gamma': 1.0,
#    'lambda_sparse': 0.01,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'entmax',
#    'n_shared': 1,
#    'n_independent': 3,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 721.5196533203125,
#   'test_rmse': 26.86111787175494,
#   'test_corr_coef': 0.9522141949844037,
#   'pruner': 'MedianPruner'},
#  ('TabNet', 'NopPruner'): {'best_score': 501.6092834472656,
#   'best_params': {'n_d': 64,
#    'n_a': 32,
#    'n_steps': 3,
#    'gamma': 1.3,
#    'lambda_sparse': 0.01,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'entmax',
#    'n_shared': 1,
#    'n_independent': 1,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 501.6092834472656,
#   'test_rmse': 22.39663553856395,
#   'test_corr_coef': 0.959963662664138,
#   'pruner': 'NopPruner'},
#  ('TabNet', 'PatientPruner'): {'best_score': 766.7186279296875,
#   'best_params': {'n_d': 32,
#    'n_a': 32,
#    'n_steps': 5,
#    'gamma': 1.0,
#    'lambda_sparse': 0.01,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'entmax',
#    'n_shared': 1,
#    'n_independent': 1,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 766.7186279296875,
#   'test_rmse': 27.689684503975258,
#   'test_corr_coef': 0.9440714641010908,
#   'pruner': 'PatientPruner'},
#  ('TabNet', 'PercentilePruner'): {'best_score': 610.1722412109375,
#   'best_params': {'n_d': 32,
#    'n_a': 16,
#    'n_steps': 7,
#    'gamma': 1.0,
#    'lambda_sparse': 0.001,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'entmax',
#    'n_shared': 1,
#    'n_independent': 1,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 610.1722412109375,
#   'test_rmse': 24.701664745740064,
#   'test_corr_coef': 0.9647668013881555,
#   'pruner': 'PercentilePruner'},
#  ('TabNet', 'SuccessiveHalvingPruner'): {'best_score': 709.545654296875,
#   'best_params': {'n_d': 64,
#    'n_a': 8,
#    'n_steps': 5,
#    'gamma': 1.0,
#    'lambda_sparse': 0.0001,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'entmax',
#    'n_shared': 1,
#    'n_independent': 1,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 709.545654296875,
#   'test_rmse': 26.63729817937388,
#   'test_corr_coef': 0.9393055399710968,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('TabNet', 'HyperbandPruner'): {'best_score': 1009.4485473632812,
#   'best_params': {'n_d': 64,
#    'n_a': 8,
#    'n_steps': 3,
#    'gamma': 1.3,
#    'lambda_sparse': 0.0001,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'entmax',
#    'n_shared': 2,
#    'n_independent': 3,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 1009.4485473632812,
#   'test_rmse': 31.77182001968539,
#   'test_corr_coef': 0.9337133951436145,
#   'pruner': 'HyperbandPruner'},
#  ('TabNet', 'ThresholdPruner'): {'best_score': 524.5145263671875,
#   'best_params': {'n_d': 32,
#    'n_a': 64,
#    'n_steps': 7,
#    'gamma': 1.0,
#    'lambda_sparse': 0.01,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'entmax',
#    'n_shared': 1,
#    'n_independent': 1,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 524.5145263671875,
#   'test_rmse': 22.902282121377937,
#   'test_corr_coef': 0.9610065410598798,
#   'pruner': 'ThresholdPruner'},
#  ('TabNet', 'WilcoxonPruner'): {'best_score': 1009.2654418945312,
#   'best_params': {'n_d': 64,
#    'n_a': 8,
#    'n_steps': 3,
#    'gamma': 2.0,
#    'lambda_sparse': 0.01,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'entmax',
#    'n_shared': 1,
#    'n_independent': 1,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 1009.2654418945312,
#   'test_rmse': 31.768938318655398,
#   'test_corr_coef': 0.9034786283748976,
#   'pruner': 'WilcoxonPruner'},
#  ('HistGradientBoosting', 'MedianPruner'): {'best_score': 898.4124907426117,
#   'best_params': {'learning_rate': 0.1,
#    'max_iter': 300,
#    'max_depth': 7,
#    'min_samples_leaf': 20,
#    'max_leaf_nodes': None,
#    'l2_regularization': 0.1,
#    'max_bins': 255,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 15,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 898.4124907426117,
#   'test_rmse': 29.97352983454921,
#   'test_corr_coef': 0.92683002681198,
#   'pruner': 'MedianPruner'},
#  ('HistGradientBoosting', 'NopPruner'): {'best_score': 911.4239385223963,
#   'best_params': {'learning_rate': 0.05,
#    'max_iter': 400,
#    'max_depth': 7,
#    'min_samples_leaf': 20,
#    'max_leaf_nodes': None,
#    'l2_regularization': 0.5,
#    'max_bins': 255,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 15,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 911.4239385223963,
#   'test_rmse': 30.189798583667237,
#   'test_corr_coef': 0.9248354324174923,
#   'pruner': 'NopPruner'},
#  ('HistGradientBoosting', 'PatientPruner'): {'best_score': 891.2421107932001,
#   'best_params': {'learning_rate': 0.15,
#    'max_iter': 100,
#    'max_depth': None,
#    'min_samples_leaf': 20,
#    'max_leaf_nodes': None,
#    'l2_regularization': 0.0,
#    'max_bins': 128,
#    'early_stopping': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 10,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 891.2421107932001,
#   'test_rmse': 29.8536783461134,
#   'test_corr_coef': 0.925135694469049,
#   'pruner': 'PatientPruner'},
#  ('HistGradientBoosting',
#   'PercentilePruner'): {'best_score': 913.2351566923057, 'best_params': {'learning_rate': 0.05,
#    'max_iter': 500,
#    'max_depth': None,
#    'min_samples_leaf': 20,
#    'max_leaf_nodes': 31,
#    'l2_regularization': 0.5,
#    'max_bins': 255,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0}, 'test_mse': 913.2351566923057, 'test_rmse': 30.219780884253705, 'test_corr_coef': 0.9241795341186559, 'pruner': 'PercentilePruner'},
#  ('HistGradientBoosting',
#   'SuccessiveHalvingPruner'): {'best_score': 908.3879560082221, 'best_params': {'learning_rate': 0.1,
#    'max_iter': 500,
#    'max_depth': None,
#    'min_samples_leaf': 20,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 0.0,
#    'max_bins': 255,
#    'early_stopping': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 10,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0}, 'test_mse': 908.3879560082221, 'test_rmse': 30.139475045332528, 'test_corr_coef': 0.9266394450142663, 'pruner': 'SuccessiveHalvingPruner'},
#  ('HistGradientBoosting', 'HyperbandPruner'): {'best_score': 887.9323976257056,
#   'best_params': {'learning_rate': 0.15,
#    'max_iter': 400,
#    'max_depth': None,
#    'min_samples_leaf': 20,
#    'max_leaf_nodes': 31,
#    'l2_regularization': 0.0,
#    'max_bins': 128,
#    'early_stopping': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 10,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 887.9323976257056,
#   'test_rmse': 29.798194536342393,
#   'test_corr_coef': 0.9240899751092941,
#   'pruner': 'HyperbandPruner'},
#  ('HistGradientBoosting', 'ThresholdPruner'): {'best_score': 887.9323976257056,
#   'best_params': {'learning_rate': 0.15,
#    'max_iter': 400,
#    'max_depth': None,
#    'min_samples_leaf': 20,
#    'max_leaf_nodes': 31,
#    'l2_regularization': 0.0,
#    'max_bins': 128,
#    'early_stopping': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 887.9323976257056,
#   'test_rmse': 29.798194536342393,
#   'test_corr_coef': 0.9240899751092941,
#   'pruner': 'ThresholdPruner'},
#  ('HistGradientBoosting', 'WilcoxonPruner'): {'best_score': 890.0188862670979,
#   'best_params': {'learning_rate': 0.1,
#    'max_iter': 400,
#    'max_depth': None,
#    'min_samples_leaf': 20,
#    'max_leaf_nodes': 31,
#    'l2_regularization': 0.1,
#    'max_bins': 255,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 15,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 890.0188862670979,
#   'test_rmse': 29.833184313229083,
#   'test_corr_coef': 0.9272488132634422,
#   'pruner': 'WilcoxonPruner'},
#  ('PGBM', 'MedianPruner'): {'best_score': 641.7479013042985,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'max_leaves': 51,
#    'min_split_gain': 0.0,
#    'reg_lambda': 1.0,
#    'feature_fraction': 0.5,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'laplace'},
#   'test_mse': 641.7479013042985,
#   'test_rmse': 25.332743659230804,
#   'test_corr_coef': 0.9490475395308383,
#   'pruner': 'MedianPruner'},
#  ('PGBM', 'NopPruner'): {'best_score': 625.065209550903,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_leaves': 44,
#    'min_split_gain': 0.1,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.7,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'studentt'},
#   'test_mse': 625.065209550903,
#   'test_rmse': 25.00130415700155,
#   'test_corr_coef': 0.9512883993327096,
#   'pruner': 'NopPruner'},
#  ('PGBM', 'PatientPruner'): {'best_score': 687.4065318349224,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'max_leaves': 59,
#    'min_split_gain': 0.1,
#    'reg_lambda': 10.0,
#    'feature_fraction': 0.5,
#    'bagging_fraction': 0.7,
#    'tree_correlation': 0.3,
#    'min_data_in_leaf': 10,
#    'max_bin': 64,
#    'distribution': 'laplace'},
#   'test_mse': 687.4065318349224,
#   'test_rmse': 26.218438775696054,
#   'test_corr_coef': 0.9430557540045342,
#   'pruner': 'PatientPruner'},
#  ('PGBM', 'PercentilePruner'): {'best_score': 741.3681958343936,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'max_leaves': 23,
#    'min_split_gain': 0.5,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.5,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 5,
#    'max_bin': 128,
#    'distribution': 'studentt'},
#   'test_mse': 741.3681958343936,
#   'test_rmse': 27.228077343697876,
#   'test_corr_coef': 0.9418232610591573,
#   'pruner': 'PercentilePruner'},
#  ('PGBM', 'SuccessiveHalvingPruner'): {'best_score': 647.070676951572,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.15,
#    'max_leaves': 41,
#    'min_split_gain': 0.0,
#    'reg_lambda': 1.0,
#    'feature_fraction': 0.5,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.3,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'studentt'},
#   'test_mse': 647.070676951572,
#   'test_rmse': 25.437583944855533,
#   'test_corr_coef': 0.9484296771280839,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('PGBM', 'HyperbandPruner'): {'best_score': 661.0973969482378,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'max_leaves': 50,
#    'min_split_gain': 0.1,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.1,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'normal'},
#   'test_mse': 661.0973969482378,
#   'test_rmse': 25.7118143457096,
#   'test_corr_coef': 0.9519790007206579,
#   'pruner': 'HyperbandPruner'},
#  ('PGBM', 'ThresholdPruner'): {'best_score': 670.8418237359856,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'max_leaves': 27,
#    'min_split_gain': 0.1,
#    'reg_lambda': 1.0,
#    'feature_fraction': 0.5,
#    'bagging_fraction': 0.7,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'laplace'},
#   'test_mse': 670.8418237359856,
#   'test_rmse': 25.900614350551333,
#   'test_corr_coef': 0.9457075112185871,
#   'pruner': 'ThresholdPruner'},
#  ('PGBM', 'WilcoxonPruner'): {'best_score': 690.3159403819556,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'max_leaves': 27,
#    'min_split_gain': 0.5,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.5,
#    'bagging_fraction': 0.7,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'laplace'},
#   'test_mse': 690.3159403819556,
#   'test_rmse': 26.273864207267945,
#   'test_corr_coef': 0.9480544469416152,
#   'pruner': 'WilcoxonPruner'}}

# %% [markdown]
# #**Best Model Analysis**

# %%
import os

def _ensure_parent_dir(path):
    parent = os.path.dirname(path)
    if parent:
        os.makedirs(parent, exist_ok=True)
    return path

import os
def get_best_models_and_predict(best_scores_autosampler, X_train, y_train, X_test, y_test, file_path):
    # Convert input data to NumPy arrays
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    # Mapping for model creation based on dictionary keys
    model_mapping = {
        'Random Forest': RandomForestRegressor,
        'Gradient Boosting': GradientBoostingRegressor,
        'XGBoost': XGBRegressor,
        'LightGBM': LGBMRegressor,
        'CatBoost': CatBoostRegressor,
        'GPBoost': GPBoostRegressor,
        'NGBoost': NGBRegressor,
        'TabNet': TabNetRegressor,
        'HistGradientBoosting': HistGradientBoostingRegressor,
        'PGBM': PGBM  # PGBM is handled separately
    }

    # Dictionary to store the best model for each type
    best_models = {}

    # Iterate over the dictionary to find the best pruner for each model type
    for (model_name, pruner), params in best_scores_autosampler.items():
        current_score = params.get('test_mse', np.inf)
        if model_name not in best_models or current_score < best_models[model_name]['score']:
            best_models[model_name] = {
                'score': current_score,
                'params': params['best_params'],
                'pruner': pruner
            }

    # Prepare a DataFrame to store predictions
    df = pd.read_csv(file_path)

    # Iterate over the best models to train and predict
    for model_name, model_info in best_models.items():
        best_params = model_info['params']
        model_class = model_mapping.get(model_name)

        if model_class is None:
            print(f"Model {model_name} is not supported or not available.")
            continue

        # Handle specific parameters or settings for model if needed
        if model_name == 'CatBoost':
            best_params.pop('verbose', None)  # Remove 'verbose' for CatBoost

        # Create an instance of the best model with the best parameters
        if model_name == 'PGBM':
            model = model_class()
            model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=best_params)
            predictions = model.predict(X_test)
        elif model_name == 'TabNet':
            model = model_class(**best_params)
            model.fit(X_train, y_train.reshape(-1, 1))
            predictions = model.predict(X_test)
            predictions = predictions.ravel()
        else:
            model = model_class(**best_params)
            model.fit(X_train, y_train)
            predictions = model.predict(X_test)

        # Add predictions to the DataFrame
        df[f'{model_name} Predictions'] = predictions

        # Plot actual vs. predicted
        plt.figure(figsize=(10, 6))
        plt.scatter(y_test, predictions, alpha=0.6)
        plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', color='red', lw=2)
        plt.xlabel("Actual WQI")
        plt.ylabel("Predicted WQI")
        plt.title(f"Actual vs. Predicted Values ({model_name})")
        plt.grid(True)
        plt.tight_layout()

        # Save the plot temporarily
        plot_path = f'temp_plot_{model_name}.png'
        _ensure_parent_dir(plot_path)
        plt.savefig(_ensure_parent_dir(plot_path))
        plt.close()

    # ✅ NEW OUTPUT DIRECTORY
    output_dir = "./drive/MyDrive/water_quality_wqi_uncertainty_analysis/hyperparameter_tuning/"
    os.makedirs(output_dir, exist_ok=True)

    output_excel_path = os.path.join(
        output_dir,
        os.path.basename(file_path).replace('.csv', '_results.xlsx')
    )

    # Save predictions and plots to Excel
    with pd.ExcelWriter(_ensure_parent_dir(output_excel_path), engine='xlsxwriter') as writer:
        # Write data to Excel
        writer
        df.to_excel(writer, sheet_name='data', index=False)

        # Get the xlsxwriter objects
        workbook = writer.book

        # Insert each plot into a separate worksheet
        for model_name in best_models.keys():
            short_model_name = ''.join([word[0] for word in model_name.split()])
            sheet_name = f'{short_model_name}_Plot'

            worksheet = workbook.add_worksheet(sheet_name)
            writer.sheets[sheet_name] = worksheet
            plot_path = f'temp_plot_{model_name}.png'
            worksheet.insert_image('A1', plot_path)

    # Clean up temporary plot files
    for model_name in best_models.keys():
        if os.path.exists(str(f'temp_plot_{model_name}.png')): os.remove(str(f'temp_plot_{model_name}.png'))

    return df, best_models

# Call the function
df, best_models = get_best_models_and_predict(best_scores_autosampler, X_train, y_train, X_test, y_test, "./drive/MyDrive/water_quality_wqi_uncertainty_analysis/data/test.csv")
# Out:
# 0:	learn: 79.2768892	total: 42.5ms	remaining: 42.4s
# 1:	learn: 76.4930474	total: 409ms	remaining: 3m 24s
# 2:	learn: 74.0251520	total: 421ms	remaining: 2m 19s
# 3:	learn: 71.7932097	total: 433ms	remaining: 1m 47s
# 4:	learn: 69.4646800	total: 444ms	remaining: 1m 28s
# 5:	learn: 67.1695588	total: 452ms	remaining: 1m 14s
# 6:	learn: 64.8958908	total: 462ms	remaining: 1m 5s
# 56:	learn: 22.8160148	total: 927ms	remaining: 15.3s
# 57:	learn: 22.3376310	total: 934ms	remaining: 15.2s
# 58:	learn: 21.9121646	total: 942ms	remaining: 15s
# 59:	learn: 21.4726667	total: 950ms	remaining: 14.9s
# 60:	learn: 21.2870479	total: 959ms	remaining: 14.8s
# 61:	learn: 21.0775536	total: 966ms	remaining: 14.6s
# 62:	learn: 20.8329788	total: 980ms	remaining: 14.6s
# 63:	learn: 20.5901688	total: 992ms	remaining: 14.5s
# 64:	learn: 20.3272840	total: 1.02s	remaining: 14.7s
# 65:	learn: 19.9454577	total: 1.06s	remaining: 15.1s
# 66:	learn: 19.7671043	total: 1.1s	remaining: 15.3s
# 67:	learn: 19.5275353	total: 1.13s	remaining: 15.6s
# 68:	learn: 19.1319335	total: 1.2s	remaining: 16.2s
# 69:	learn: 18.9346918	total: 1.26s	remaining: 16.8s
# 70:	learn: 18.8466786	total: 1.33s	remaining: 17.5s
# 71:	learn: 18.5604598	total: 1.43s	remaining: 18.5s
# 72:	learn: 18.3160690	total: 1.54s	remaining: 19.5s
# 73:	learn: 18.1353456	total: 1.66s	remaining: 20.8s
# 74:	learn: 17.8492999	total: 1.73s	remaining: 21.4s
# 75:	learn: 17.6675235	total: 1.87s	remaining: 22.8s
# 76:	learn: 17.4359934	total: 1.89s	remaining: 22.6s
# 77:	learn: 17.1653272	total: 1.9s	remaining: 22.4s
# 78:	learn: 16.8929033	total: 1.91s	remaining: 22.3s
# 79:	learn: 16.6319575	total: 1.92s	remaining: 22.1s
# 80:	learn: 16.3853354	total: 1.93s	remaining: 21.9s
# 81:	learn: 16.1109541	total: 1.94s	remaining: 21.7s
# 82:	learn: 15.8638925	total: 1.95s	remaining: 21.5s
# 83:	learn: 15.5339981	total: 1.96s	remaining: 21.3s
# 84:	learn: 15.2766933	total: 1.96s	remaining: 21.1s
# 85:	learn: 15.1436613	total: 1.97s	remaining: 21s
# 86:	learn: 14.8989527	total: 1.98s	remaining: 20.8s
# 87:	learn: 14.7243154	total: 1.99s	remaining: 20.6s
# 88:	learn: 14.5426018	total: 2s	remaining: 20.5s
# 89:	learn: 14.3339824	total: 2.01s	remaining: 20.3s
# 90:	learn: 14.1637276	total: 2.02s	remaining: 20.1s
# 91:	learn: 13.9326312	total: 2.02s	remaining: 20s
# 92:	learn: 13.6965790	total: 2.03s	remaining: 19.8s
# 93:	learn: 13.5620356	total: 2.04s	remaining: 19.7s
# 94:	learn: 13.3488460	total: 2.05s	remaining: 19.5s
# 95:	learn: 13.1348686	total: 2.06s	remaining: 19.4s
# 96:	learn: 12.9831743	total: 2.07s	remaining: 19.3s
# 97:	learn: 12.8012510	total: 2.08s	remaining: 19.1s
# 98:	learn: 12.6477030	total: 2.09s	remaining: 19s
# 99:	learn: 12.4403211	total: 2.1s	remaining: 18.9s
# 100:	learn: 12.3018448	total: 2.1s	remaining: 18.7s
# 101:	learn: 12.1712945	total: 2.11s	remaining: 18.6s
# 102:	learn: 12.0212176	total: 2.12s	remaining: 18.5s
# 338:	learn: 1.2556504	total: 4.67s	remaining: 9.11s
# 339:	learn: 1.2429031	total: 4.68s	remaining: 9.09s
# 340:	learn: 1.2315245	total: 4.69s	remaining: 9.07s
# 341:	learn: 1.2192328	total: 4.7s	remaining: 9.04s
# 342:	learn: 1.2076194	total: 4.71s	remaining: 9.02s
# 343:	learn: 1.2015110	total: 4.72s	remaining: 9s
# 344:	learn: 1.1913297	total: 4.74s	remaining: 8.99s
# 345:	learn: 1.1825842	total: 4.75s	remaining: 8.97s
# 346:	learn: 1.1749561	total: 4.76s	remaining: 8.96s
# 347:	learn: 1.1635061	total: 4.78s	remaining: 8.96s
# 348:	learn: 1.1508215	total: 4.8s	remaining: 8.96s
# 349:	learn: 1.1437122	total: 4.83s	remaining: 8.96s
# 350:	learn: 1.1365844	total: 4.84s	remaining: 8.94s
# 351:	learn: 1.1257619	total: 4.85s	remaining: 8.92s
# 352:	learn: 1.1192098	total: 4.86s	remaining: 8.9s
# 353:	learn: 1.1130159	total: 4.87s	remaining: 8.88s
# 354:	learn: 1.1062472	total: 4.87s	remaining: 8.86s
# 355:	learn: 1.0965427	total: 4.88s	remaining: 8.83s
# 356:	learn: 1.0909443	total: 4.89s	remaining: 8.82s
# 357:	learn: 1.0792875	total: 4.9s	remaining: 8.79s
# 358:	learn: 1.0734210	total: 4.92s	remaining: 8.78s
# 359:	learn: 1.0628446	total: 4.93s	remaining: 8.76s
# 360:	learn: 1.0523151	total: 4.93s	remaining: 8.73s
# 361:	learn: 1.0452235	total: 4.94s	remaining: 8.71s
# 362:	learn: 1.0338779	total: 4.95s	remaining: 8.69s
# 363:	learn: 1.0245933	total: 4.96s	remaining: 8.67s
# 364:	learn: 1.0187209	total: 4.97s	remaining: 8.65s
# 365:	learn: 1.0127302	total: 4.99s	remaining: 8.64s
# 366:	learn: 1.0090085	total: 5s	remaining: 8.62s
# 367:	learn: 1.0033370	total: 5.01s	remaining: 8.6s
# 368:	learn: 0.9960081	total: 5.02s	remaining: 8.59s
# 369:	learn: 0.9897484	total: 5.03s	remaining: 8.56s
# 370:	learn: 0.9867202	total: 5.04s	remaining: 8.54s
# 371:	learn: 0.9767621	total: 5.05s	remaining: 8.52s
# 372:	learn: 0.9706479	total: 5.06s	remaining: 8.5s
# 373:	learn: 0.9658152	total: 5.07s	remaining: 8.48s
# 374:	learn: 0.9549475	total: 5.07s	remaining: 8.46s
# 375:	learn: 0.9455447	total: 5.08s	remaining: 8.43s
# 376:	learn: 0.9378532	total: 5.09s	remaining: 8.41s
# 377:	learn: 0.9287157	total: 5.1s	remaining: 8.39s
# 378:	learn: 0.9202727	total: 5.11s	remaining: 8.37s
# 379:	learn: 0.9171239	total: 5.12s	remaining: 8.35s
# 380:	learn: 0.9049377	total: 5.12s	remaining: 8.33s
# 381:	learn: 0.8976981	total: 5.13s	remaining: 8.31s
# 382:	learn: 0.8919593	total: 5.14s	remaining: 8.29s
# 383:	learn: 0.8894874	total: 5.15s	remaining: 8.27s
# 384:	learn: 0.8793854	total: 5.16s	remaining: 8.24s
# 573:	learn: 0.2483299	total: 7.68s	remaining: 5.7s
# 574:	learn: 0.2468964	total: 7.71s	remaining: 5.7s
# 575:	learn: 0.2447481	total: 7.73s	remaining: 5.69s
# 576:	learn: 0.2438582	total: 7.75s	remaining: 5.68s
# 577:	learn: 0.2413531	total: 7.78s	remaining: 5.68s
# 578:	learn: 0.2395623	total: 7.79s	remaining: 5.67s
# 579:	learn: 0.2385364	total: 7.81s	remaining: 5.65s
# 580:	learn: 0.2367015	total: 7.82s	remaining: 5.64s
# 581:	learn: 0.2355631	total: 7.83s	remaining: 5.63s
# 582:	learn: 0.2344140	total: 7.85s	remaining: 5.61s
# 583:	learn: 0.2328401	total: 7.87s	remaining: 5.61s
# 584:	learn: 0.2310897	total: 7.89s	remaining: 5.6s
# 585:	learn: 0.2299994	total: 7.91s	remaining: 5.59s
# 586:	learn: 0.2293615	total: 7.93s	remaining: 5.58s
# 587:	learn: 0.2273001	total: 7.95s	remaining: 5.57s
# 588:	learn: 0.2253123	total: 7.98s	remaining: 5.57s
# 589:	learn: 0.2242511	total: 8.01s	remaining: 5.56s
# 590:	learn: 0.2236487	total: 8.03s	remaining: 5.56s
# 591:	learn: 0.2229024	total: 8.05s	remaining: 5.55s
# 592:	learn: 0.2208332	total: 8.07s	remaining: 5.54s
# 593:	learn: 0.2200728	total: 8.1s	remaining: 5.54s
# 594:	learn: 0.2176565	total: 8.13s	remaining: 5.54s
# 595:	learn: 0.2163218	total: 8.15s	remaining: 5.53s
# 596:	learn: 0.2137850	total: 8.17s	remaining: 5.52s
# 597:	learn: 0.2125905	total: 8.2s	remaining: 5.51s
# 598:	learn: 0.2114458	total: 8.22s	remaining: 5.5s
# 599:	learn: 0.2100955	total: 8.23s	remaining: 5.49s
# 600:	learn: 0.2078971	total: 8.25s	remaining: 5.48s
# 601:	learn: 0.2060524	total: 8.27s	remaining: 5.47s
# 602:	learn: 0.2047497	total: 8.29s	remaining: 5.46s
# 603:	learn: 0.2040763	total: 8.31s	remaining: 5.45s
# 604:	learn: 0.2031470	total: 8.33s	remaining: 5.44s
# 605:	learn: 0.2013706	total: 8.35s	remaining: 5.43s
# 606:	learn: 0.1996095	total: 8.37s	remaining: 5.42s
# 607:	learn: 0.1988030	total: 8.4s	remaining: 5.42s
# 608:	learn: 0.1975077	total: 8.42s	remaining: 5.41s
# 609:	learn: 0.1962154	total: 8.44s	remaining: 5.4s
# 610:	learn: 0.1950852	total: 8.46s	remaining: 5.39s
# 611:	learn: 0.1937905	total: 8.48s	remaining: 5.38s
# 612:	learn: 0.1924867	total: 8.51s	remaining: 5.37s
# 613:	learn: 0.1920023	total: 8.55s	remaining: 5.37s
# 614:	learn: 0.1909943	total: 8.57s	remaining: 5.36s
# 615:	learn: 0.1899554	total: 8.6s	remaining: 5.36s
# 616:	learn: 0.1882603	total: 8.63s	remaining: 5.36s
# 617:	learn: 0.1866102	total: 8.65s	remaining: 5.35s
# 618:	learn: 0.1850706	total: 8.67s	remaining: 5.34s
# 619:	learn: 0.1843559	total: 8.69s	remaining: 5.33s
# 808:	learn: 0.0593906	total: 14.3s	remaining: 3.37s
# 809:	learn: 0.0592161	total: 14.3s	remaining: 3.35s
# 810:	learn: 0.0585869	total: 14.3s	remaining: 3.33s
# 811:	learn: 0.0582713	total: 14.3s	remaining: 3.32s
# 812:	learn: 0.0576311	total: 14.4s	remaining: 3.3s
# 813:	learn: 0.0568692	total: 14.4s	remaining: 3.28s
# 814:	learn: 0.0562143	total: 14.4s	remaining: 3.27s
# 815:	learn: 0.0559478	total: 14.4s	remaining: 3.25s
# 816:	learn: 0.0557902	total: 14.5s	remaining: 3.24s
# 817:	learn: 0.0555947	total: 14.5s	remaining: 3.22s
# 818:	learn: 0.0552639	total: 14.5s	remaining: 3.21s
# 819:	learn: 0.0551047	total: 14.5s	remaining: 3.19s
# 820:	learn: 0.0545225	total: 14.6s	remaining: 3.17s
# 821:	learn: 0.0541687	total: 14.6s	remaining: 3.16s
# 822:	learn: 0.0539036	total: 14.6s	remaining: 3.14s
# 823:	learn: 0.0535284	total: 14.6s	remaining: 3.12s
# 824:	learn: 0.0531763	total: 14.7s	remaining: 3.11s
# 825:	learn: 0.0525966	total: 14.7s	remaining: 3.09s
# 826:	learn: 0.0523491	total: 14.7s	remaining: 3.08s
# 827:	learn: 0.0520162	total: 14.7s	remaining: 3.06s
# 828:	learn: 0.0518306	total: 14.8s	remaining: 3.05s
# 829:	learn: 0.0514504	total: 14.8s	remaining: 3.03s
# 830:	learn: 0.0513348	total: 14.8s	remaining: 3.02s
# 831:	learn: 0.0511079	total: 14.9s	remaining: 3s
# 832:	learn: 0.0509587	total: 14.9s	remaining: 2.99s
# 833:	learn: 0.0504379	total: 14.9s	remaining: 2.97s
# 834:	learn: 0.0499888	total: 14.9s	remaining: 2.95s
# 835:	learn: 0.0495219	total: 15s	remaining: 2.94s
# 836:	learn: 0.0492200	total: 15s	remaining: 2.92s
# 837:	learn: 0.0488011	total: 15s	remaining: 2.9s
# 838:	learn: 0.0483876	total: 15s	remaining: 2.88s
# 839:	learn: 0.0481667	total: 15.1s	remaining: 2.87s
# 840:	learn: 0.0480261	total: 15.1s	remaining: 2.85s
# 841:	learn: 0.0478395	total: 15.1s	remaining: 2.83s
# 842:	learn: 0.0476307	total: 15.1s	remaining: 2.82s
# 843:	learn: 0.0474577	total: 15.1s	remaining: 2.8s
# 844:	learn: 0.0472326	total: 15.2s	remaining: 2.79s
# 845:	learn: 0.0469128	total: 15.2s	remaining: 2.77s
# 846:	learn: 0.0465146	total: 15.3s	remaining: 2.75s
# 847:	learn: 0.0461934	total: 15.3s	remaining: 2.74s
# 848:	learn: 0.0457258	total: 15.3s	remaining: 2.72s
# 849:	learn: 0.0454904	total: 15.3s	remaining: 2.71s
# 850:	learn: 0.0452636	total: 15.4s	remaining: 2.69s
# 851:	learn: 0.0448767	total: 15.4s	remaining: 2.67s
# 852:	learn: 0.0445781	total: 15.4s	remaining: 2.65s
# 853:	learn: 0.0444894	total: 15.4s	remaining: 2.64s
# 854:	learn: 0.0443746	total: 15.4s	remaining: 2.62s
# 855:	learn: 0.0441488	total: 15.5s	remaining: 2.6s
# 856:	learn: 0.0438336	total: 15.5s	remaining: 2.58s
# 857:	learn: 0.0437393	total: 15.5s	remaining: 2.57s
# 858:	learn: 0.0435665	total: 15.5s	remaining: 2.55s
# 859:	learn: 0.0434877	total: 15.6s	remaining: 2.53s
# 860:	learn: 0.0432717	total: 15.6s	remaining: 2.52s
# 861:	learn: 0.0429647	total: 15.6s	remaining: 2.5s
# 862:	learn: 0.0426620	total: 15.7s	remaining: 2.48s
# 863:	learn: 0.0422744	total: 15.7s	remaining: 2.47s
# 864:	learn: 0.0420356	total: 15.7s	remaining: 2.45s
# 865:	learn: 0.0419192	total: 15.7s	remaining: 2.43s
# 866:	learn: 0.0417462	total: 15.7s	remaining: 2.41s
# 867:	learn: 0.0415623	total: 15.7s	remaining: 2.39s
# 868:	learn: 0.0412230	total: 15.8s	remaining: 2.38s
# 869:	learn: 0.0409753	total: 15.8s	remaining: 2.36s
# 870:	learn: 0.0405612	total: 15.8s	remaining: 2.34s
# 871:	learn: 0.0404373	total: 15.8s	remaining: 2.32s
# 872:	learn: 0.0400179	total: 15.8s	remaining: 2.31s
# 873:	learn: 0.0397416	total: 15.9s	remaining: 2.29s
# 874:	learn: 0.0394690	total: 15.9s	remaining: 2.27s
# 875:	learn: 0.0391960	total: 15.9s	remaining: 2.25s
# 876:	learn: 0.0389335	total: 15.9s	remaining: 2.24s
# 877:	learn: 0.0386389	total: 16s	remaining: 2.22s
# 878:	learn: 0.0383688	total: 16s	remaining: 2.2s
# 879:	learn: 0.0382517	total: 16s	remaining: 2.18s
# 880:	learn: 0.0380049	total: 16s	remaining: 2.17s
# 881:	learn: 0.0379231	total: 16.1s	remaining: 2.15s
# 882:	learn: 0.0376067	total: 16.1s	remaining: 2.13s
# 883:	learn: 0.0373493	total: 16.1s	remaining: 2.12s
# 884:	learn: 0.0371358	total: 16.1s	remaining: 2.1s
# 885:	learn: 0.0367764	total: 16.2s	remaining: 2.08s
# 886:	learn: 0.0366270	total: 16.2s	remaining: 2.06s
# 887:	learn: 0.0364054	total: 16.2s	remaining: 2.05s
# 888:	learn: 0.0361503	total: 16.2s	remaining: 2.03s
# 889:	learn: 0.0360106	total: 16.2s	remaining: 2.01s
# 890:	learn: 0.0358522	total: 16.3s	remaining: 1.99s
# 891:	learn: 0.0357272	total: 16.3s	remaining: 1.97s
# 892:	learn: 0.0355916	total: 16.3s	remaining: 1.95s
# 893:	learn: 0.0354191	total: 16.3s	remaining: 1.93s
# 894:	learn: 0.0352287	total: 16.3s	remaining: 1.91s
# 895:	learn: 0.0350548	total: 16.3s	remaining: 1.9s
# 896:	learn: 0.0348611	total: 16.3s	remaining: 1.88s
# 897:	learn: 0.0347289	total: 16.4s	remaining: 1.86s
# 898:	learn: 0.0346182	total: 16.4s	remaining: 1.84s
# 899:	learn: 0.0345449	total: 16.4s	remaining: 1.82s
# 900:	learn: 0.0343092	total: 16.4s	remaining: 1.8s
# 901:	learn: 0.0340889	total: 16.4s	remaining: 1.78s
# 902:	learn: 0.0339729	total: 16.4s	remaining: 1.77s
# 903:	learn: 0.0337490	total: 16.5s	remaining: 1.75s
# 904:	learn: 0.0336146	total: 16.5s	remaining: 1.73s
# 905:	learn: 0.0333566	total: 16.5s	remaining: 1.71s
# 906:	learn: 0.0330374	total: 16.5s	remaining: 1.69s
# 907:	learn: 0.0327711	total: 16.5s	remaining: 1.67s
# 908:	learn: 0.0324201	total: 16.5s	remaining: 1.66s
# 909:	learn: 0.0321110	total: 16.6s	remaining: 1.64s
# 910:	learn: 0.0318938	total: 16.6s	remaining: 1.62s
# 911:	learn: 0.0315366	total: 16.6s	remaining: 1.6s
# 912:	learn: 0.0313639	total: 16.6s	remaining: 1.58s
# 913:	learn: 0.0311717	total: 16.6s	remaining: 1.56s
# 914:	learn: 0.0308596	total: 16.7s	remaining: 1.55s
# 915:	learn: 0.0305809	total: 16.7s	remaining: 1.53s
# 916:	learn: 0.0305046	total: 16.7s	remaining: 1.51s
# 917:	learn: 0.0303280	total: 16.7s	remaining: 1.49s
# 918:	learn: 0.0300700	total: 16.7s	remaining: 1.47s
# 919:	learn: 0.0298514	total: 16.7s	remaining: 1.46s
# 920:	learn: 0.0297638	total: 16.7s	remaining: 1.44s
# 921:	learn: 0.0295544	total: 16.8s	remaining: 1.42s
# 922:	learn: 0.0294210	total: 16.8s	remaining: 1.4s
# 923:	learn: 0.0293474	total: 16.8s	remaining: 1.38s
# 924:	learn: 0.0292596	total: 16.8s	remaining: 1.36s
# 925:	learn: 0.0291454	total: 16.8s	remaining: 1.34s
# 926:	learn: 0.0290568	total: 16.8s	remaining: 1.32s
# ...
# Estimator 100/500, Train metric: 3.7622
# Estimator 101/500, Train metric: 3.6881
# Estimator 102/500, Train metric: 3.6844
# Estimator 103/500, Train metric: 3.6192
# Estimator 104/500, Train metric: 3.5927
# Estimator 105/500, Train metric: 3.5303
# Estimator 106/500, Train metric: 3.5222
# Estimator 107/500, Train metric: 3.4682
# Estimator 108/500, Train metric: 3.4571
# Estimator 109/500, Train metric: 3.4377
# Estimator 110/500, Train metric: 3.3553
# Estimator 111/500, Train metric: 3.2801
# Estimator 112/500, Train metric: 3.2176
# Estimator 113/500, Train metric: 3.1613
# Estimator 114/500, Train metric: 3.1080
# Estimator 115/500, Train metric: 3.0573
# Estimator 116/500, Train metric: 2.9859
# Estimator 117/500, Train metric: 2.9730
# Estimator 118/500, Train metric: 2.9296
# Estimator 119/500, Train metric: 2.8965
# Estimator 120/500, Train metric: 2.9009
# Estimator 121/500, Train metric: 2.8608
# Estimator 122/500, Train metric: 2.8112
# Estimator 123/500, Train metric: 2.7595
# Estimator 124/500, Train metric: 2.7531
# Estimator 125/500, Train metric: 2.7504
# Estimator 126/500, Train metric: 2.7046
# Estimator 127/500, Train metric: 2.6665
# Estimator 128/500, Train metric: 2.6133
# Estimator 129/500, Train metric: 2.5952
# Estimator 130/500, Train metric: 2.5684
# Estimator 131/500, Train metric: 2.5373
# Estimator 132/500, Train metric: 2.4778
# Estimator 133/500, Train metric: 2.4727
# Estimator 134/500, Train metric: 2.4536
# Estimator 135/500, Train metric: 2.4486
# Estimator 136/500, Train metric: 2.4457
# Estimator 137/500, Train metric: 2.3908
# Estimator 138/500, Train metric: 2.3836
# Estimator 139/500, Train metric: 2.3847
# Estimator 140/500, Train metric: 2.3891
# Estimator 141/500, Train metric: 2.3768
# Estimator 142/500, Train metric: 2.3734
# Estimator 143/500, Train metric: 2.3522
# Estimator 144/500, Train metric: 2.3353
# Estimator 145/500, Train metric: 2.3354
# Estimator 146/500, Train metric: 2.3136
# Estimator 147/500, Train metric: 2.2841
# Estimator 148/500, Train metric: 2.2878
# Estimator 149/500, Train metric: 2.2455
# Estimator 150/500, Train metric: 2.2470
# Estimator 151/500, Train metric: 2.2499
# Estimator 152/500, Train metric: 2.2543
# Estimator 153/500, Train metric: 2.2149
# Estimator 154/500, Train metric: 2.2025
# Estimator 155/500, Train metric: 2.1715
# Estimator 156/500, Train metric: 2.1213
# Estimator 157/500, Train metric: 2.1136
# Estimator 158/500, Train metric: 2.0779
# Estimator 159/500, Train metric: 2.0546
# Estimator 160/500, Train metric: 2.0246
# Estimator 161/500, Train metric: 2.0170
# Estimator 162/500, Train metric: 2.0145
# Estimator 163/500, Train metric: 1.9762
# Estimator 164/500, Train metric: 1.9738
# Estimator 165/500, Train metric: 1.9564
# Estimator 166/500, Train metric: 1.9560
# Estimator 167/500, Train metric: 1.9097
# Estimator 168/500, Train metric: 1.8866
# Estimator 169/500, Train metric: 1.8851
# Estimator 170/500, Train metric: 1.8841
# Estimator 171/500, Train metric: 1.8600
# Estimator 172/500, Train metric: 1.8607
# Estimator 173/500, Train metric: 1.8342
# Estimator 174/500, Train metric: 1.8330
# Estimator 175/500, Train metric: 1.8380
# Estimator 176/500, Train metric: 1.8187
# Estimator 177/500, Train metric: 1.8208
# Estimator 178/500, Train metric: 1.8212
# Estimator 179/500, Train metric: 1.8249
# Estimator 180/500, Train metric: 1.8280
# Estimator 181/500, Train metric: 1.8283
# Estimator 182/500, Train metric: 1.8289
# Estimator 183/500, Train metric: 1.8334
# Estimator 184/500, Train metric: 1.8072
# Estimator 185/500, Train metric: 1.7911
# Estimator 186/500, Train metric: 1.7957
# Estimator 187/500, Train metric: 1.8022
# Estimator 188/500, Train metric: 1.7802
# Estimator 189/500, Train metric: 1.7801
# Estimator 190/500, Train metric: 1.7849
# Estimator 191/500, Train metric: 1.7898
# Estimator 192/500, Train metric: 1.7890
# Estimator 193/500, Train metric: 1.7917
# Estimator 194/500, Train metric: 1.7904
# Estimator 195/500, Train metric: 1.7697
# Estimator 196/500, Train metric: 1.7751
# Estimator 197/500, Train metric: 1.7672
# Estimator 198/500, Train metric: 1.7508
# Estimator 199/500, Train metric: 1.7197
# Estimator 200/500, Train metric: 1.7196
# Estimator 201/500, Train metric: 1.7024
# Estimator 202/500, Train metric: 1.7010
# Estimator 203/500, Train metric: 1.6930
# Estimator 204/500, Train metric: 1.6794
# Estimator 205/500, Train metric: 1.6531
# Estimator 206/500, Train metric: 1.6519
# Estimator 207/500, Train metric: 1.6293
# Estimator 208/500, Train metric: 1.5966
# Estimator 209/500, Train metric: 1.5781
# Estimator 210/500, Train metric: 1.5813
# Estimator 211/500, Train metric: 1.5852
# Estimator 212/500, Train metric: 1.5690
# Estimator 213/500, Train metric: 1.5562
# Estimator 214/500, Train metric: 1.5563
# Estimator 215/500, Train metric: 1.5401
# Estimator 216/500, Train metric: 1.5428
# Estimator 217/500, Train metric: 1.5463
# Estimator 218/500, Train metric: 1.5284
# Estimator 219/500, Train metric: 1.5293
# Estimator 220/500, Train metric: 1.5326
# Estimator 221/500, Train metric: 1.4999
# Estimator 222/500, Train metric: 1.5038
# Estimator 223/500, Train metric: 1.4740
# Estimator 224/500, Train metric: 1.4537
# Estimator 225/500, Train metric: 1.4382
# Estimator 226/500, Train metric: 1.4384
# Estimator 227/500, Train metric: 1.4242
# Estimator 228/500, Train metric: 1.3920
# Estimator 229/500, Train metric: 1.3796
# Estimator 230/500, Train metric: 1.3796
# Estimator 231/500, Train metric: 1.3678
# Estimator 232/500, Train metric: 1.3676
# Estimator 233/500, Train metric: 1.3676
# Estimator 234/500, Train metric: 1.3701
# Estimator 235/500, Train metric: 1.3739
# Estimator 236/500, Train metric: 1.3782
# Estimator 237/500, Train metric: 1.3737
# Estimator 238/500, Train metric: 1.3479
# Estimator 239/500, Train metric: 1.3491
# Estimator 240/500, Train metric: 1.3530
# Estimator 241/500, Train metric: 1.3528
# Estimator 242/500, Train metric: 1.3531
# Estimator 243/500, Train metric: 1.3394
# Estimator 244/500, Train metric: 1.3278
# Estimator 245/500, Train metric: 1.3185
# Estimator 246/500, Train metric: 1.2983
# Estimator 247/500, Train metric: 1.2720
# Estimator 248/500, Train metric: 1.2621
# Estimator 249/500, Train metric: 1.2453
# Estimator 250/500, Train metric: 1.2373
# Estimator 251/500, Train metric: 1.2361
# Estimator 252/500, Train metric: 1.2115
# Estimator 253/500, Train metric: 1.1931
# Estimator 254/500, Train metric: 1.1731
# Estimator 255/500, Train metric: 1.1733
# Estimator 256/500, Train metric: 1.1736
# Estimator 257/500, Train metric: 1.1511
# Estimator 258/500, Train metric: 1.1280
# Estimator 259/500, Train metric: 1.1181
# Estimator 260/500, Train metric: 1.1196
# Estimator 261/500, Train metric: 1.0981
# Estimator 262/500, Train metric: 1.0906
# Estimator 263/500, Train metric: 1.0718
# Estimator 264/500, Train metric: 1.0739
# Estimator 265/500, Train metric: 1.0581
# Estimator 266/500, Train metric: 1.0588
# Estimator 267/500, Train metric: 1.0404
# Estimator 268/500, Train metric: 1.0434
# Estimator 269/500, Train metric: 1.0248
# Estimator 270/500, Train metric: 1.0172
# Estimator 271/500, Train metric: 0.9985
# Estimator 272/500, Train metric: 0.9797
# Estimator 273/500, Train metric: 0.9647
# Estimator 274/500, Train metric: 0.9658
# Estimator 275/500, Train metric: 0.9496
# Estimator 276/500, Train metric: 0.9311
# Estimator 277/500, Train metric: 0.9191
# Estimator 278/500, Train metric: 0.9048
# Estimator 279/500, Train metric: 0.9050
# Estimator 280/500, Train metric: 0.8892
# Estimator 281/500, Train metric: 0.8820
# Estimator 282/500, Train metric: 0.8734
# Estimator 283/500, Train metric: 0.8631
# Estimator 284/500, Train metric: 0.8626
# Estimator 285/500, Train metric: 0.8450
# Estimator 286/500, Train metric: 0.8411
# Estimator 287/500, Train metric: 0.8283
# Estimator 288/500, Train metric: 0.8181
# Estimator 289/500, Train metric: 0.8025
# Estimator 290/500, Train metric: 0.8014
# Estimator 291/500, Train metric: 0.7968
# Estimator 292/500, Train metric: 0.7905
# Estimator 293/500, Train metric: 0.7799
# Estimator 294/500, Train metric: 0.7796
# Estimator 295/500, Train metric: 0.7618
# Estimator 296/500, Train metric: 0.7582
# Estimator 297/500, Train metric: 0.7438
# Estimator 298/500, Train metric: 0.7384
# Estimator 299/500, Train metric: 0.7292
# Estimator 300/500, Train metric: 0.7288
# Estimator 301/500, Train metric: 0.7175
# Estimator 302/500, Train metric: 0.7175
# Estimator 303/500, Train metric: 0.7116
# Estimator 304/500, Train metric: 0.7095
# Estimator 305/500, Train metric: 0.7094
# Estimator 306/500, Train metric: 0.6968
# Estimator 307/500, Train metric: 0.6958
# Estimator 308/500, Train metric: 0.6951
# Estimator 309/500, Train metric: 0.6837
# Estimator 310/500, Train metric: 0.6781
# Estimator 311/500, Train metric: 0.6702
# Estimator 312/500, Train metric: 0.6676
# Estimator 313/500, Train metric: 0.6576
# Estimator 314/500, Train metric: 0.6531
# Estimator 315/500, Train metric: 0.6459
# Estimator 316/500, Train metric: 0.6445
# Estimator 317/500, Train metric: 0.6401
# Estimator 318/500, Train metric: 0.6336
# Estimator 319/500, Train metric: 0.6260
# Estimator 320/500, Train metric: 0.6166
# Estimator 321/500, Train metric: 0.6143
# Estimator 322/500, Train metric: 0.6136
# Estimator 323/500, Train metric: 0.6130
# Estimator 324/500, Train metric: 0.6123
# Estimator 325/500, Train metric: 0.6073
# Estimator 326/500, Train metric: 0.6032
# Estimator 327/500, Train metric: 0.6027
# Estimator 328/500, Train metric: 0.5987
# Estimator 329/500, Train metric: 0.5980
# Estimator 330/500, Train metric: 0.5865
# Estimator 331/500, Train metric: 0.5847
# Estimator 332/500, Train metric: 0.5846
# Estimator 333/500, Train metric: 0.5839
# Estimator 334/500, Train metric: 0.5852
# Estimator 335/500, Train metric: 0.5786
# Estimator 336/500, Train metric: 0.5789
# Estimator 337/500, Train metric: 0.5792
# Estimator 338/500, Train metric: 0.5688
# Estimator 339/500, Train metric: 0.5690
# Estimator 340/500, Train metric: 0.5599
# Estimator 341/500, Train metric: 0.5606
# Estimator 342/500, Train metric: 0.5528
# Estimator 343/500, Train metric: 0.5528
# Estimator 344/500, Train metric: 0.5531
# Estimator 345/500, Train metric: 0.5492
# Estimator 346/500, Train metric: 0.5460
# Estimator 347/500, Train metric: 0.5391
# Estimator 348/500, Train metric: 0.5387
# Estimator 349/500, Train metric: 0.5349
# Estimator 350/500, Train metric: 0.5327
# Estimator 351/500, Train metric: 0.5285
# Estimator 352/500, Train metric: 0.5281
# Estimator 353/500, Train metric: 0.5184
# Estimator 354/500, Train metric: 0.5180
# Estimator 355/500, Train metric: 0.5161
# Estimator 356/500, Train metric: 0.5150
# Estimator 357/500, Train metric: 0.5114
# Estimator 358/500, Train metric: 0.5017
# Estimator 359/500, Train metric: 0.4998
# Estimator 360/500, Train metric: 0.4909
# Estimator 361/500, Train metric: 0.4883
# Estimator 362/500, Train metric: 0.4879
# Estimator 363/500, Train metric: 0.4869
# Estimator 364/500, Train metric: 0.4866
# Estimator 365/500, Train metric: 0.4838
# Estimator 366/500, Train metric: 0.4827
# Estimator 367/500, Train metric: 0.4822
# Estimator 368/500, Train metric: 0.4744
# Estimator 369/500, Train metric: 0.4647
# Estimator 370/500, Train metric: 0.4644
# Estimator 371/500, Train metric: 0.4642
# Estimator 372/500, Train metric: 0.4568
# Estimator 373/500, Train metric: 0.4478
# Estimator 374/500, Train metric: 0.4478
# Estimator 375/500, Train metric: 0.4415
# Estimator 376/500, Train metric: 0.4344
# Estimator 377/500, Train metric: 0.4271
# Estimator 378/500, Train metric: 0.4272
# Estimator 379/500, Train metric: 0.4265
# Estimator 380/500, Train metric: 0.4252
# Estimator 381/500, Train metric: 0.4250
# Estimator 382/500, Train metric: 0.4249
# Estimator 383/500, Train metric: 0.4246
# Estimator 384/500, Train metric: 0.4199
# Estimator 385/500, Train metric: 0.4194
# Estimator 386/500, Train metric: 0.4194
# Estimator 387/500, Train metric: 0.4191
# Estimator 388/500, Train metric: 0.4189
# Estimator 389/500, Train metric: 0.4111
# Estimator 390/500, Train metric: 0.4123
# Estimator 391/500, Train metric: 0.4123
# Estimator 392/500, Train metric: 0.4130
# Estimator 393/500, Train metric: 0.4049
# Estimator 394/500, Train metric: 0.3987
# Estimator 395/500, Train metric: 0.3964
# Estimator 396/500, Train metric: 0.3897
# Estimator 397/500, Train metric: 0.3846
# Estimator 398/500, Train metric: 0.3846
# Estimator 399/500, Train metric: 0.3852
# Estimator 400/500, Train metric: 0.3857
# Estimator 401/500, Train metric: 0.3824
# Estimator 402/500, Train metric: 0.3765
# Estimator 403/500, Train metric: 0.3764
# Estimator 404/500, Train metric: 0.3771
# Estimator 405/500, Train metric: 0.3710
# Estimator 406/500, Train metric: 0.3718
# Estimator 407/500, Train metric: 0.3649
# Estimator 408/500, Train metric: 0.3646
# Estimator 409/500, Train metric: 0.3615
# Estimator 410/500, Train metric: 0.3623
# Estimator 411/500, Train metric: 0.3633
# Estimator 412/500, Train metric: 0.3571
# Estimator 413/500, Train metric: 0.3584
# Estimator 414/500, Train metric: 0.3596
# Estimator 415/500, Train metric: 0.3592
# Estimator 416/500, Train metric: 0.3528
# Estimator 417/500, Train metric: 0.3501
# Estimator 418/500, Train metric: 0.3509
# Estimator 419/500, Train metric: 0.3491
# Estimator 420/500, Train metric: 0.3429
# Estimator 421/500, Train metric: 0.3442
# Estimator 422/500, Train metric: 0.3450
# Estimator 423/500, Train metric: 0.3459
# Estimator 424/500, Train metric: 0.3445
# Estimator 425/500, Train metric: 0.3415
# Estimator 426/500, Train metric: 0.3415
# Estimator 427/500, Train metric: 0.3429
# Estimator 428/500, Train metric: 0.3430
# Estimator 429/500, Train metric: 0.3403
# Estimator 430/500, Train metric: 0.3347
# Estimator 431/500, Train metric: 0.3292
# Estimator 432/500, Train metric: 0.3289
# Estimator 433/500, Train metric: 0.3243
# Estimator 434/500, Train metric: 0.3220
# Estimator 435/500, Train metric: 0.3182
# Estimator 436/500, Train metric: 0.3163
# Estimator 437/500, Train metric: 0.3163
# Estimator 438/500, Train metric: 0.3163
# Estimator 439/500, Train metric: 0.3151
# Estimator 440/500, Train metric: 0.3129
# Estimator 441/500, Train metric: 0.3090
# Estimator 442/500, Train metric: 0.3090
# Estimator 443/500, Train metric: 0.3077
# Estimator 444/500, Train metric: 0.3060
# Estimator 445/500, Train metric: 0.3019
# Estimator 446/500, Train metric: 0.2980
# Estimator 447/500, Train metric: 0.2936
# Estimator 448/500, Train metric: 0.2893
# Estimator 449/500, Train metric: 0.2846
# Estimator 450/500, Train metric: 0.2799
# Estimator 451/500, Train metric: 0.2799
# Estimator 452/500, Train metric: 0.2799
# Estimator 453/500, Train metric: 0.2800
# Estimator 454/500, Train metric: 0.2799
# Estimator 455/500, Train metric: 0.2769
# Estimator 456/500, Train metric: 0.2741
# Estimator 457/500, Train metric: 0.2734
# Estimator 458/500, Train metric: 0.2700
# Estimator 459/500, Train metric: 0.2699
# Estimator 460/500, Train metric: 0.2700
# Estimator 461/500, Train metric: 0.2704
# Estimator 462/500, Train metric: 0.2704
# Estimator 463/500, Train metric: 0.2712
# Estimator 464/500, Train metric: 0.2673
# Estimator 465/500, Train metric: 0.2681
# Estimator 466/500, Train metric: 0.2685
# Estimator 467/500, Train metric: 0.2647
# Estimator 468/500, Train metric: 0.2654
# Estimator 469/500, Train metric: 0.2661
# Estimator 470/500, Train metric: 0.2668
# Estimator 471/500, Train metric: 0.2677
# Estimator 472/500, Train metric: 0.2683
# Estimator 473/500, Train metric: 0.2683
# Estimator 474/500, Train metric: 0.2681
# Estimator 475/500, Train metric: 0.2681
# Estimator 476/500, Train metric: 0.2642
# Estimator 477/500, Train metric: 0.2649
# Estimator 478/500, Train metric: 0.2649
# Estimator 479/500, Train metric: 0.2643
# Estimator 480/500, Train metric: 0.2652
# Estimator 481/500, Train metric: 0.2662
# Estimator 482/500, Train metric: 0.2670
# Estimator 483/500, Train metric: 0.2670
# Estimator 484/500, Train metric: 0.2634
# Estimator 485/500, Train metric: 0.2612
# Estimator 486/500, Train metric: 0.2612
# Estimator 487/500, Train metric: 0.2590
# Estimator 488/500, Train metric: 0.2590
# Estimator 489/500, Train metric: 0.2599
# Estimator 490/500, Train metric: 0.2556
# Estimator 491/500, Train metric: 0.2518
# Estimator 492/500, Train metric: 0.2518
# Estimator 493/500, Train metric: 0.2518
# Estimator 494/500, Train metric: 0.2518
# Estimator 495/500, Train metric: 0.2518
# Estimator 496/500, Train metric: 0.2524
# Estimator 497/500, Train metric: 0.2531
# Estimator 498/500, Train metric: 0.2497
# Estimator 499/500, Train metric: 0.2496

# %%
plot_best_scores(best_scores_autosampler,"./drive/MyDrive/water_quality_wqi_uncertainty_analysis/hyperparameter_tuning/test_results.xlsx")

# %%
generate_interpretml_explanations_summary_pruners(best_scores_autosampler, X_train, y_train, x_test, feature_names,excel_file_path = "./drive/MyDrive/water_quality_wqi_uncertainty_analysis/hyperparameter_tuning/test_results.xlsx")
# Out:
# WARNING:shap:Using 190 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/82 [00:00<?, ?it/s]
# WARNING:shap:Using 190 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/82 [00:00<?, ?it/s]
# WARNING:shap:Using 190 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/82 [00:00<?, ?it/s]
# WARNING:shap:Using 190 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/82 [00:00<?, ?it/s]
# WARNING:shap:Using 190 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/82 [00:00<?, ?it/s]
# WARNING:shap:Using 190 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/82 [00:00<?, ?it/s]
